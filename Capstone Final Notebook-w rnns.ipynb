# %% [markdown]
# # Capstone Project: Audio Based Emotion Classifier - RNN with Attention Models

# %% [markdown]
# After the first edition of this project, I really wanted to see how recurrent neural networks could be used to make predictions based on audio data. Luckily, I stumbled upon a repository that detailed the architecture of a model that used both convolutional layers and recurrent layers with attention for the purposes to recognizing speech commands. The attention layer allows the model to focus more on certain aspects of the audio, such as the transitions between phonemes. After modifying the architecture to suit the structure of my data, I was able to get this model to train on 4 sets of features: 80 mel frequency cepstral coefficients, 80 gammatone frequency cepstral coefficients, 60 linear frequency cepstral coefficients along with the zero-crossing rate, spectral centroid, spectral bandwidth and RMS for each time step, and finally a fusion of all the features concatenated at every timestep. The inspiration behind using the LFCC features and the fusion of features came from another research paper on using RNNs for audio scene classification, which has been a very important resource for me recently.
#
# These two resources can be found here:
#
# __https://github.com/douglas125/SpeechCmdRecognition__
#
# __https://arxiv.org/pdf/1703.04770.pdf__

# %% [markdown]
# ## Set Path to Project Folder

# %%
# Set PATH to 'Classifying Emotions With Audio' directory
# Make sure this folder contains 'Data Sets' with TESS and SAVEE inside, as well as the 'Models' Folder
PATH = '/Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Classifying Emotions With Audio'

# %% [markdown]
# ## Import libraries

# %%
# Standard Library Imports
import csv
import os
import numpy as np
import pandas as pd
import re
import librosa
from librosa import display
import IPython.display as ipd
from IPython.display import display
import time
import pickle
import seaborn as sn
import matplotlib.pyplot as plt
import sounddevice as sd
import math
from scipy.io.wavfile import write

#Keras Imports
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import (Dense, 
                                     Conv2D, 
                                     MaxPooling1D, 
                                     MaxPooling2D, 
                                     Flatten, 
                                     Dense, 
                                     Dropout,
                                     Conv1D, 
                                     Activation, 
                                     BatchNormalization, 
                                     AveragePooling1D,
                                     MaxPool1D,
                                     GlobalMaxPool2D,
                                     LSTM,
                                     Bidirectional,
                                     Embedding,
                                     GRU,
                                     SimpleRNN
                                    )
from tensorflow.keras import layers as L
from tensorflow.keras import backend as K

from tensorflow.keras.regularizers import l2, L1L2

from tensorflow.keras.callbacks import (EarlyStopping, 
                                        LearningRateScheduler,
                                        ModelCheckpoint, 
                                        TensorBoard, 
                                        ReduceLROnPlateau)

from tensorflow.keras import optimizers
from keras import callbacks

from tensorflow.keras.utils import to_categorical

# SKLearn Imports
from sklearn.metrics import (confusion_matrix, 
                             accuracy_score, 
                             classification_report)

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from sklearn.linear_model import LogisticRegressionCV
from sklearn.utils import resample
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, RandomTreesEmbedding
from sklearn.svm import LinearSVC, SVC
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix, plot_confusion_matrix

from kapre.time_frequency import Melspectrogram, Spectrogram
from kapre.utils import Normalization2D

from tensorflow.keras.models import Model, load_model
# Out:
# /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Classifying Emotions With Audio/Capstone_Project_Env/lib/python3.8/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Classifying Emotions With Audio/Capstone_Project_Env/lib/python3.8/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# ### Extracting 80 MFCCs

# %%
# Loading the balanced dataframe containing information about each audio file.
os.chdir(os.path.join(PATH,'DataFrames'))
audiodata_balanced = pd.read_csv("Balanced Audio Data Iteration #2.csv", index_col = False)
audiodata_balanced
# Out:
#                 Filename Dataset Sex Speaker  Duration  Emotion
# 0                h05.wav   SAVEE   M      KL      3.38        5
# 1               sa04.wav   SAVEE   M      KL      4.73        3
# 2                h11.wav   SAVEE   M      KL      5.53        5
# 3               sa10.wav   SAVEE   M      KL      4.15        3
# 4                d08.wav   SAVEE   M      KL      3.29        1
# ..                   ...     ...  ..     ...       ...      ...
# 835  YAF_tough_happy.wav    TESS   F     YAF      1.73        5
# 836      OAF_late_ps.wav    TESS   F     OAF      1.96        6
# 837       OAF_fat_ps.wav    TESS   F     OAF      1.98        6
# 838     OAF_life_sad.wav    TESS   F     OAF      2.56        3
# 839  OAF_check_angry.wav    TESS   F     OAF      1.65        0
#
# [840 rows x 6 columns]

# %%
# This script will create a 3D array of MFCCs for each audio file.

os.chdir(os.path.join(PATH,'Data Sets'))
df = audiodata_balanced

# Specify number of MFCCs, hop length and sampling rate here.

n_mfcc = 80
hop_length = 512
sr = 44100


# A function to access the file structure of TESS dataset.

def emotion_reverse(emotion):
    
    x = str
    if emotion == 0:
        x = 'angry'
    if emotion == 1:
        x = 'disgust'
    if emotion == 2:
        x = 'fear'
    if emotion == 3:
        x = 'sad'
    if emotion == 4:
        x = 'neutral'
    if emotion == 5:
        x = 'happy'
    if emotion == 6:
        x = 'pleasant_surprised'
    return (x)

# Our dataframe will be sized so that each observation corresponds to 1 second of audio. The number of MFCCs taken is determined by the specified hop length.
# We'll start by creating an empty array of the appropriate size.

df = audiodata_balanced

# Loading a sample audiofile.
i=0

filename = df.iloc[i]['Filename']
dataset = df.iloc[i]['Dataset']
speaker = df.iloc[i]['Speaker']
emotion = df.iloc[i]['Emotion']

if (dataset=='SAVEE'):
    y, sr = librosa.load(os.path.join(dataset, speaker, filename), sr = sr)
elif(dataset=='TESS'):
    emotion = emotion_reverse(emotion)
    speaker_emotion = (f'{speaker}_{emotion}')
    y, sr = librosa.load(os.path.join(dataset, speaker_emotion, filename), sr = sr)

# Getting the duration of the sample and padding with zeros so that the length is an integer.  

duration = librosa.get_duration(y,sr)
pieces = math.ceil(duration)

length = sr*pieces

pad_length = length - len(y)
y = np.pad(y,((0,pad_length)),'constant')

# Taking the first 1 second chunk from the audiofile and extracting MFCCs from that chunk.

start=0
end=sr

chunk = y[start:end]

mfccs = librosa.feature.mfcc(chunk, sr = sr, n_mfcc=n_mfcc, hop_length = hop_length)

# Using the MFCCs from the 1 second chunk to create an empty array.

chunk_MFCC_array = np.empty(shape =(1,mfccs.shape[0],mfccs.shape[1]))
chunk_MFCC_array[i]=mfccs

c=0
p=1

# Creating a new dataframe to track unique identifiers, and the number of 1 second pieces generated from each audiofile.

index_df = pd.DataFrame(columns = df.columns)
index_df.insert(0,'ID',0)
index_df.insert(1,'Pieces',0)
index_df = index_df.append(df.iloc[i])
index_df.iloc[c,0] = int(i)
index_df.iloc[c,1] = (f'{p}/{pieces}')

c+=1
p+=1

# Adding the remaining 1 second pieces from the sample audiofile to the two new dataframes.

for n in range(pieces-1):
    
    start +=sr
    end +=sr
    
    chunk = y[start:end]
    mfccs = librosa.feature.mfcc(chunk, sr = sr, n_mfcc=n_mfcc, hop_length = hop_length)
    
    mfccs = mfccs.reshape((1,mfccs.shape[0],mfccs.shape[1]))
    
    chunk_MFCC_array = np.append(chunk_MFCC_array,mfccs,axis=0)
    
    index_df = index_df.append(df.iloc[i])
    index_df.iloc[c,0] = int(i)
    index_df.iloc[c,1] = (f'{p}/{pieces}')
    
    c+=1
    p+=1
    
# Slicing all remaining audiofiles into 1 second pieces, extracting each ones set of MFCCs, then adding each set to our dataframe of MFCCs, as well as updating our index dataframe.

for i in range(1, len(df)):
    
    filename = df.iloc[i]['Filename']
    dataset = df.iloc[i]['Dataset']
    speaker = df.iloc[i]['Speaker']
    emotion = df.iloc[i]['Emotion']
    
    if (dataset=='SAVEE'):
        
        y, sr = librosa.load(os.path.join(dataset, speaker, filename), sr = sr)

    elif(dataset=='TESS'):
        emotion = emotion_reverse(emotion)
        speaker_emotion = (f'{speaker}_{emotion}')
        
        y, sr = librosa.load(os.path.join(dataset, speaker_emotion, filename), sr = sr)
        
    duration = librosa.get_duration(y,sr)
        
    pieces = math.ceil(duration)
    
    length = sr*pieces

    pad_length = length - len(y)
    
    y = np.pad(y,((0,pad_length)),'constant')

    start=0
    end=sr
    p=1

    for n in range(pieces):

        chunk = y[start:end]
        mfccs = librosa.feature.mfcc(chunk, sr = sr, n_mfcc=n_mfcc, hop_length = hop_length)

        mfccs = mfccs.reshape((1,mfccs.shape[0],mfccs.shape[1]))

        chunk_MFCC_array = np.append(chunk_MFCC_array,mfccs,axis=0)

        index_df = index_df.append(df.iloc[i])
        index_df.iloc[c,0] = int(i)
        index_df.iloc[c,1] = (f'{p}/{pieces}')

        c+=1
        p+=1
        start +=sr
        end +=sr
        
        
        print('\r',f'{c} arrays added',end='')
    

# Saving the new dataframes.

os.chdir(os.path.join(PATH,'DataFrames'))
np.save('80_MFCC_array_1s_Chunks.npy', chunk_MFCC_array)
index_df.to_csv('1s_chunk_index_df.csv', index=False)
# Out:
#  2913 arrays added

# %% [markdown]
# ### Extracting 80 GFCCs

# %%
# This function will extract GFCCs from an audio file.
# Extracted from spafe.

import numpy as np
import scipy
import scipy.signal
import scipy.fftpack

from librosa import util
from librosa import filters
#from ..util.exceptions import ParameterError

from librosa.core.time_frequency import fft_frequencies
from librosa.core.audio import zero_crossings, to_mono
from librosa.core.spectrum import power_to_db, _spectrogram
from librosa.core.constantq import cqt, hybrid_cqt
from librosa.core.pitch import estimate_tuning
from spafe.fbanks.gammatone_fbanks import gammatone_filter_banks
from spafe.fbanks.linear_fbanks import linear_filter_banks

def gfcc_test(y=None, sr=22050, S=None, n_gfcc=20, dct_type=2, norm='ortho', lifter=0, **kwargs):


    if S is None:
        S = power_to_db(gammaspectrogram(y=y, sr=sr, **kwargs))

    M = scipy.fftpack.dct(S, axis=0, type=dct_type, norm=norm)[:n_gfcc]

    if lifter > 0:
        M *= 1 + (lifter / 2) * np.sin(np.pi * np.arange(1, 1 + n_gfcc, dtype=M.dtype) / lifter)[:, np.newaxis]
        return M
    elif lifter == 0:
        return M
    else:
        raise ParameterError('GFCC lifter={} must be a non-negative number'.format(lifter))

        
        
def gammaspectrogram(y=None, sr=22050, S=None, n_fft=2048, hop_length=512,
                   win_length=None, window='hann', center=True, pad_mode='reflect',
                   power=1.0, **kwargs):


    S, n_fft = _spectrogram(y=y, S=S, n_fft=n_fft, hop_length=hop_length, power=power,
                            win_length=win_length, window=window, center=center,
                            pad_mode=pad_mode)


    gamma_basis = gammatone_filter_banks(fs=sr,nfft=n_fft,nfilts=128)

    return np.dot(gamma_basis, S)

# %%
# This script will create a 3D array of GFCCs for each audio file. It functions in almost exactly the same way as the code used to extract MFCCs per each 1 second slice of audio.

os.chdir(os.path.join(PATH,'DataFrames'))
audiodata_balanced = pd.read_csv("Balanced Audio Data Iteration #2.csv", index_col = False)
df = audiodata_balanced

# Specify number of GFCCs, hop length and sampling rate here.

n_gfcc = 80
hop_length = 512
sr = 44100

# A function to access the file structure of TESS dataset.

def emotion_reverse(emotion):
    
    x = str
    if emotion == 0:
        x = 'angry'
    if emotion == 1:
        x = 'disgust'
    if emotion == 2:
        x = 'fear'
    if emotion == 3:
        x = 'sad'
    if emotion == 4:
        x = 'neutral'
    if emotion == 5:
        x = 'happy'
    if emotion == 6:
        x = 'pleasant_surprised'
    return (x)

# Our dataframe will be sized so that each observation corresponds to 1 second of audio. The number of GFCCs taken is determined by the specified hop length.
# We'll start by creating an empty array of the appropriate size.

df = audiodata_balanced

os.chdir(os.path.join(PATH,'Data Sets'))

# Loading a sample audiofile.

i=0
c=1 

filename = df.iloc[i]['Filename']
dataset = df.iloc[i]['Dataset']
speaker = df.iloc[i]['Speaker']
emotion = df.iloc[i]['Emotion']

if (dataset=='SAVEE'):
    y, sr = librosa.load(os.path.join(dataset, speaker, filename), sr = sr)
elif(dataset=='TESS'):
    emotion = emotion_reverse(emotion)
    speaker_emotion = (f'{speaker}_{emotion}')
    y, sr = librosa.load(os.path.join(dataset, speaker_emotion, filename), sr = sr)
    
# Getting the duration of the sample and padding with zeros so that the length is an integer. 
    
duration = librosa.get_duration(y,sr)
pieces = math.ceil(duration)

length = sr*pieces

pad_length = length - len(y)
y = np.pad(y,((0,pad_length)),'constant')

# Taking the first 1 second chunk from the audiofile and extracting GFCCs from that chunk.

start=0
end=sr

chunk = y[start:end]

gfccs = gfcc_test(chunk, sr = sr, n_gfcc=n_gfcc, hop_length=hop_length)

# Using the GFCCs from the 1 second chunk to create an empty array.

chunk_GFCC_array = np.empty(shape =(1,gfccs.shape[0],gfccs.shape[1]))
chunk_GFCC_array[i]=gfccs

# Adding the remaining 1 second pieces from the sample audiofile to the two new dataframes.

for n in range(pieces-1):
    c+=1
    start +=sr
    end +=sr
    
    chunk = y[start:end]
    len(chunk)
    gfccs = gfcc_test(chunk, sr = sr, n_gfcc=n_gfcc, hop_length=hop_length)
    
    gfccs = gfccs.reshape((1,gfccs.shape[0],gfccs.shape[1]))
    
    chunk_GFCC_array = np.append(chunk_GFCC_array,gfccs,axis=0)

# Adding the remaining 1 second slices of audio to our dataframe.
    
for i in range(1, len(df)):
    
    filename = df.iloc[i]['Filename']
    dataset = df.iloc[i]['Dataset']
    speaker = df.iloc[i]['Speaker']
    emotion = df.iloc[i]['Emotion']
    
    if (dataset=='SAVEE'):
        
        y, sr = librosa.load(os.path.join(dataset, speaker, filename), sr = sr)

    elif(dataset=='TESS'):
        emotion = emotion_reverse(emotion)
        speaker_emotion = (f'{speaker}_{emotion}')
        
        y, sr = librosa.load(os.path.join(dataset, speaker_emotion, filename), sr = sr)
        
    duration = librosa.get_duration(y,sr)   
    pieces = math.ceil(duration)
    length = sr*pieces
    pad_length = length - len(y)
    y = np.pad(y,((0,pad_length)),'constant')

    start=0
    end=sr
    p=1

    for n in range(pieces):

        chunk = y[start:end]
        gfccs = gfcc_test(chunk, sr = sr, n_gfcc=n_gfcc, hop_length=hop_length)

        gfccs = gfccs.reshape((1,gfccs.shape[0],gfccs.shape[1]))

        chunk_GFCC_array = np.append(chunk_GFCC_array,gfccs,axis=0)

        start +=sr
        end +=sr
        c+=1
        
        print('\r',f'{c} arrays added',end='')
        
# Saving our new dataframe       
    
os.chdir(os.path.join(PATH,'DataFrames'))
np.save('80_GFCC_array_1s_Chunks.npy', chunk_GFCC_array)
# Out:
#  2913 arrays added

# %% [markdown]
# ### Extracting Linear Filterbank Cepstral Coefficients

# %%
# This function will extract LFCCs from an audio file.

import numpy as np
import scipy
import scipy.signal
import scipy.fftpack

from librosa import util
from librosa import filters
#from ..util.exceptions import ParameterError

from librosa.core.time_frequency import fft_frequencies
from librosa.core.audio import zero_crossings, to_mono
from librosa.core.spectrum import power_to_db, _spectrogram
from librosa.core.constantq import cqt, hybrid_cqt
from librosa.core.pitch import estimate_tuning
from spafe.fbanks.gammatone_fbanks import gammatone_filter_banks
from spafe.fbanks.linear_fbanks import linear_filter_banks
import math

def lin_test(y=None, sr=22050, S=None, n_lfcc=20, dct_type=2, norm='ortho', lifter=0, **kwargs):


    if S is None:
        S = power_to_db(linspectrogram(y=y, sr=sr, **kwargs))

    M = scipy.fftpack.dct(S, axis=0, type=dct_type, norm=norm)[:n_lfcc]

    if lifter > 0:
        M *= 1 + (lifter / 2) * np.sin(np.pi * np.arange(1, 1 + n_lfcc, dtype=M.dtype) / lifter)[:, np.newaxis]
        return M
    elif lifter == 0:
        return M
    else:
        raise ParameterError('GFCC lifter={} must be a non-negative number'.format(lifter))

        
        
def linspectrogram(y=None, sr=22050, S=None, n_fft=2048, hop_length=512,
                   win_length=None, window='hann', center=True, pad_mode='reflect',
                   power=1.0, **kwargs):


    S, n_fft = _spectrogram(y=y, S=S, n_fft=n_fft, hop_length=hop_length, power=power,
                            win_length=win_length, window=window, center=center,
                            pad_mode=pad_mode)


    linear_basis = linear_filter_banks(fs=sr,nfft=n_fft,nfilts=128)
    

    return np.dot(linear_basis, S)

# %%
# This script will create a 3D array of LFCCs for each audio file, plus the zero-crossing rate, spectral centroid, spectral bandwidth, and short-time energy with RMS. 
# It functions in almost exactly the same way as the code used to extract MFCCs & GFCCs. 

os.chdir(os.path.join(PATH,'DataFrames'))
audiodata_balanced = pd.read_csv("Balanced Audio Data Iteration #2.csv", index_col = False)

start_time = time.time()
df = audiodata_balanced

n_lfcc = 60
hop_length = 512
sr = 44100

def emotion_reverse(emotion):
    
    x = str
    if emotion == 0:
        x = 'angry'
    if emotion == 1:
        x = 'disgust'
    if emotion == 2:
        x = 'fear'
    if emotion == 3:
        x = 'sad'
    if emotion == 4:
        x = 'neutral'
    if emotion == 5:
        x = 'happy'
    if emotion == 6:
        x = 'pleasant_surprised'
    return (x)


df = audiodata_balanced

os.chdir(os.path.join(PATH,'Data Sets'))

i=0

filename = df.iloc[i]['Filename']
dataset = df.iloc[i]['Dataset']
speaker = df.iloc[i]['Speaker']
emotion = df.iloc[i]['Emotion']


if (dataset=='SAVEE'):
    y, sr = librosa.load(os.path.join(dataset, speaker, filename), sr = sr)
elif(dataset=='TESS'):
    emotion = emotion_reverse(emotion)
    speaker_emotion = (f'{speaker}_{emotion}')
    y, sr = librosa.load(os.path.join(dataset, speaker_emotion, filename), sr = sr)
    
duration = librosa.get_duration(y,sr)
pieces = math.ceil(duration)
length = sr*pieces
pad_length = length - len(y)
y = np.pad(y,((0,pad_length)),'constant')

start=0
end=sr

chunk = y[start:end]

lfccs = lin_test(chunk, sr = sr, n_lfcc=n_lfcc)

z0 = librosa.feature.zero_crossing_rate(chunk)
sc = librosa.feature.spectral_centroid(chunk, sr)
sbw = librosa.feature.spectral_bandwidth(chunk, sr)
rms = librosa.feature.rms(chunk)

lfccs = np.append(lfccs,z0,axis=0)
lfccs = np.append(lfccs,sc,axis=0)
lfccs = np.append(lfccs,sbw,axis=0)
lfccs = np.append(lfccs,rms,axis=0)


chunk_LFCC_array = np.empty(shape =(1,lfccs.shape[0],lfccs.shape[1]))
chunk_LFCC_array[i]=lfccs

c=1


for n in range(pieces-1):
    
    start +=sr
    end +=sr
    
    chunk = y[start:end]
    len(chunk)
    lfccs = lin_test(chunk, sr = sr, n_lfcc=n_lfcc)
    
    z0 = librosa.feature.zero_crossing_rate(chunk)
    sc = librosa.feature.spectral_centroid(chunk, sr)
    sbw = librosa.feature.spectral_bandwidth(chunk, sr)
    rms = librosa.feature.rms(chunk)
    
    lfccs = np.append(lfccs,z0,axis=0)
    lfccs = np.append(lfccs,sc,axis=0)
    lfccs = np.append(lfccs,sbw,axis=0)
    lfccs = np.append(lfccs,rms,axis=0)
    
    lfccs = lfccs.reshape((1,lfccs.shape[0],lfccs.shape[1]))
    
    chunk_LFCC_array = np.append(chunk_LFCC_array,lfccs,axis=0)
    
    c+=1
    
for i in range(1, len(df)):
    
    filename = df.iloc[i]['Filename']
    dataset = df.iloc[i]['Dataset']
    speaker = df.iloc[i]['Speaker']
    emotion = df.iloc[i]['Emotion']
    
    if (dataset=='SAVEE'):
        
        y, sr = librosa.load(os.path.join(dataset, speaker, filename), sr = sr)

    elif(dataset=='TESS'):
        emotion = emotion_reverse(emotion)
        speaker_emotion = (f'{speaker}_{emotion}')
        
        y, sr = librosa.load(os.path.join(dataset, speaker_emotion, filename), sr = sr)
        
    duration = librosa.get_duration(y,sr)    
    pieces = math.ceil(duration)
    length = sr*pieces
    pad_length = length - len(y)
    y = np.pad(y,((0,pad_length)),'constant')

    start=0
    end=sr

    for n in range(pieces):

        chunk = y[start:end]
        lfccs = lin_test(chunk, sr = sr, n_lfcc=n_lfcc)
        
        z0 = librosa.feature.zero_crossing_rate(chunk)
        sc = librosa.feature.spectral_centroid(chunk, sr)
        sbw = librosa.feature.spectral_bandwidth(chunk, sr)
        rms = librosa.feature.rms(chunk)

        lfccs = np.append(lfccs,z0,axis=0)
        lfccs = np.append(lfccs,sc,axis=0)
        lfccs = np.append(lfccs,sbw,axis=0)
        lfccs = np.append(lfccs,rms,axis=0)

        lfccs = lfccs.reshape((1,lfccs.shape[0],lfccs.shape[1]))

        chunk_LFCC_array = np.append(chunk_LFCC_array,lfccs,axis=0)

        c+=1
        start +=sr
        end +=sr
        
        
        print('\r',f'{c} arrays added',end='')
    
os.chdir(os.path.join(PATH,'DataFrames'))
np.save('60_LFCC_array.npy', chunk_LFCC_array)
index_df.to_csv('1s_chunk_index_df.csv')
# Out:
#  2913 arrays added

# %%
index_df=pd.read_csv('1s_chunk_index_df.csv')
index_df
# Out:
#       Unnamed: 0     ID Pieces             Filename Dataset Sex Speaker  \
# 0              0    0.0    1/4              h05.wav   SAVEE   M      KL
# 1              0    0.0    2/4              h05.wav   SAVEE   M      KL
# 2              0    0.0    3/4              h05.wav   SAVEE   M      KL
# 3              0    0.0    4/4              h05.wav   SAVEE   M      KL
# 4              1    1.0    1/5             sa04.wav   SAVEE   M      KL
# ...          ...    ...    ...                  ...     ...  ..     ...
# 2908         838  838.0    1/3     OAF_life_sad.wav    TESS   F     OAF
# 2909         838  838.0    2/3     OAF_life_sad.wav    TESS   F     OAF
# 2910         838  838.0    3/3     OAF_life_sad.wav    TESS   F     OAF
# 2911         839  839.0    1/2  OAF_check_angry.wav    TESS   F     OAF
# 2912         839  839.0    2/2  OAF_check_angry.wav    TESS   F     OAF
#
#       Duration  Emotion
# 0         3.38        5
# 1         3.38        5
# 2         3.38        5
# 3         3.38        5
# 4         4.73        3
# ...        ...      ...
# 2908      2.56        3
# 2909      2.56        3
# 2910      2.56        3
# 2911      1.65        0
# 2912      1.65        0
#
# [2913 rows x 9 columns]

# %% [markdown]
# ## Preprocessing

# %%
# From here we can load the dataframes containing MFCCs, GFCCs, and LFCCs, as well as the index_df containing necessary information about each.
os.chdir(os.path.join(PATH,'DataFrames'))

audiodata_balanced = pd.read_csv("Balanced Audio Data Iteration #2.csv", index_col = False)

index_df=pd.read_csv('1s_chunk_index_df.csv')

chunk_MFCC_array = np.load('80_MFCC_array_1s_Chunks.npy')
chunk_GFCC_array = np.load('80_GFCC_array_1s_Chunks.npy')
chunk_LFCC_array = np.load('60_LFCC_array.npy')

print(f'MFCC array shape:{chunk_MFCC_array.shape}, GFCC array shape:{chunk_GFCC_array.shape}, LFCC array shape:{chunk_LFCC_array.shape}')

display(index_df)
# Out:
# MFCC array shape:(2913, 80, 87), GFCC array shape:(2913, 80, 87), LFCC array shape:(2913, 64, 87)
#          ID Pieces             Filename Dataset Sex Speaker  Duration  Emotion
# 0       0.0    1/4              h05.wav   SAVEE   M      KL      3.38        5
# 1       0.0    2/4              h05.wav   SAVEE   M      KL      3.38        5
# 2       0.0    3/4              h05.wav   SAVEE   M      KL      3.38        5
# 3       0.0    4/4              h05.wav   SAVEE   M      KL      3.38        5
# 4       1.0    1/5             sa04.wav   SAVEE   M      KL      4.73        3
# ...     ...    ...                  ...     ...  ..     ...       ...      ...
# 2908  838.0    1/3     OAF_life_sad.wav    TESS   F     OAF      2.56        3
# 2909  838.0    2/3     OAF_life_sad.wav    TESS   F     OAF      2.56        3
# 2910  838.0    3/3     OAF_life_sad.wav    TESS   F     OAF      2.56        3
# 2911  839.0    1/2  OAF_check_angry.wav    TESS   F     OAF      1.65        0
# 2912  839.0    2/2  OAF_check_angry.wav    TESS   F     OAF      1.65        0
#
# [2913 rows x 8 columns]

# %%
# We'll train/test split our data, stratifying to maintain a balance of classes across 'emotion'

X = audiodata_balanced.iloc[:,:5]
y = audiodata_balanced.iloc[:,5]

X_train, X_test, y_train, y_test = train_test_split(X,y, 
                                                    test_size = 0.3, 
                                                    random_state = 18, 
                                                    stratify=y)

# We'll use the train/test split to pull out corresponding indices from index_df, which tells us which 1s clips belong to single files.

Train_index = index_df[index_df.ID.isin((X_train.index))]
Test_index = index_df[index_df.ID.isin((X_test.index))]

# From these indices we'll create equivalent arrays for each set of features.

MFCC_X_train = chunk_MFCC_array[Train_index.index]
MFCC_X_test = chunk_MFCC_array[Test_index.index]
GFCC_X_train = chunk_GFCC_array[Train_index.index]
GFCC_X_test = chunk_GFCC_array[Test_index.index]
LFCC_X_train = chunk_LFCC_array[Train_index.index]
LFCC_X_test = chunk_LFCC_array[Test_index.index]

# Declaring y_train and y_test to correspond to the dataframes of sliced audio.

y_train = Train_index.loc[:,'Emotion']
y_test = Test_index.loc[:,'Emotion']

# Resetting indices and converting y_train/y_test to numpy for future use.

Train_index = Train_index.reset_index()
Test_index = Test_index.reset_index()

y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# Standard scaling each row across all timesteps for every feature set.

for i in range(MFCC_X_train.shape[1]):
    
    scaler = StandardScaler()
    
    scaler.fit(MFCC_X_train[:,i,:])
    
    MFCC_X_train[:,i,:] = scaler.transform(MFCC_X_train[:,i,:])
    MFCC_X_test[:,i,:] = scaler.transform(MFCC_X_test[:,i,:])
    
for i in range(GFCC_X_train.shape[1]):
    
    scaler = StandardScaler()
    scaler.fit(GFCC_X_train[:,i,:])
    
    GFCC_X_train[:,i,:] = scaler.transform(GFCC_X_train[:,i,:])
    GFCC_X_test[:,i,:] = scaler.transform(GFCC_X_test[:,i,:])

for i in range(LFCC_X_train.shape[1]):
    
    scaler = StandardScaler()
    scaler.fit(LFCC_X_train[:,i,:])
    
    LFCC_X_train[:,i,:] = scaler.transform(LFCC_X_train[:,i,:])
    LFCC_X_test[:,i,:] = scaler.transform(LFCC_X_test[:,i,:])
    
# Expanding array dimensions so that they're in the appropriate format for a neural network.

MFCC_X_train = np.expand_dims(MFCC_X_train,-1)
MFCC_X_test = np.expand_dims(MFCC_X_test,-1)
GFCC_X_train = np.expand_dims(GFCC_X_train,-1)
GFCC_X_test = np.expand_dims(GFCC_X_test,-1)
LFCC_X_train = np.expand_dims(LFCC_X_train,-1)
LFCC_X_test = np.expand_dims(LFCC_X_test,-1)

# Creating a feature fusion array from each independant feature set.
    
Fusion_X_train = np.concatenate([MFCC_X_train, GFCC_X_train, LFCC_X_train],axis=1)
Fusion_X_test = np.concatenate([MFCC_X_test, GFCC_X_test, LFCC_X_test],axis=1)

# Transposing all arrays so that they're in the appropriate format for RNNs.

MFCC_X_train = MFCC_X_train.transpose(0,2,1,3)
MFCC_X_test = MFCC_X_test.transpose(0,2,1,3)
GFCC_X_train = GFCC_X_train.transpose(0,2,1,3)
GFCC_X_test = GFCC_X_test.transpose(0,2,1,3)
LFCC_X_train = LFCC_X_train.transpose(0,2,1,3)
LFCC_X_test = LFCC_X_test.transpose(0,2,1,3)
Fusion_X_train = Fusion_X_train.transpose(0,2,1,3)
Fusion_X_test = Fusion_X_test.transpose(0,2,1,3)
    
print(f'MFCC X train shape: {MFCC_X_train.shape}')
print(f'MFCC X test shape: {MFCC_X_test.shape}')
print(f'GFCC X train shape: {GFCC_X_train.shape}')
print(f'GFCC X test shape: {GFCC_X_test.shape}')
print(f'LFCC X train shape: {LFCC_X_train.shape}')
print(f'LFCC X test shape: {LFCC_X_test.shape}')
print(f'Fusion X train shape: {Fusion_X_train.shape}')
print(f'Fusion X test shape: {Fusion_X_test.shape}')
# Out:
# MFCC X train shape: (2073, 87, 80, 1)
# MFCC X test shape: (840, 87, 80, 1)
# GFCC X train shape: (2073, 87, 80, 1)
# GFCC X test shape: (840, 87, 80, 1)
# LFCC X train shape: (2073, 87, 64, 1)
# LFCC X test shape: (840, 87, 64, 1)
# Fusion X train shape: (2073, 87, 224, 1)
# Fusion X test shape: (840, 87, 224, 1)

# %% [markdown]
# ## LFCC Kernel SVM Test

# %% [markdown]
# Before we go onto using the RNN model, we are going to test the predictive power of our LFCC features using an RBF kernel SVM.

# %%
# This will take mean value of each feature in our LFCC data frame and scale it accordingly with a StandardScaler.

LFCC_X_train_2D = LFCC_X_train[:,:,:,0]
LFCC_X_test_2D = LFCC_X_test[:,:,:,0]

LFCC_X_train_2D = LFCC_X_train_2D.mean(axis=1)
LFCC_X_test_2D = LFCC_X_test_2D.mean(axis=1)

scaler = StandardScaler()
scaler.fit(LFCC_X_train_2D)
LFCC_X_train_2D = scaler.transform(LFCC_X_train_2D)
LFCC_X_test_2D = scaler.transform(LFCC_X_test_2D)

LFCC_X_train_2D.shape
# Out:
# (2073, 64)

# %%
# Testing an RBF kernel SVM with a manually optimized C value

my_RBF_kernel_SVM = SVC(C=100, max_iter = 10000, probability=True)

my_RBF_kernel_SVM.fit(LFCC_X_train_2D, y_train)

train_score =  my_RBF_kernel_SVM.score(LFCC_X_train_2D, y_train)
test_score =  my_RBF_kernel_SVM.score(LFCC_X_test_2D, y_test)

print('Train score:', train_score)
print('Test score:', test_score)
# Out:
# Train score: 0.9604438012542209
# Test score: 0.594047619047619

# %%
# This will combine the predictions of every 1 second chunk of audio from each audiofile. This is done through multiplicative probabilistic voting.

# Taking the prediction probabilites of the test set from our SVM.
X_test_proba = my_RBF_kernel_SVM.predict_proba(LFCC_X_test_2D)

# Creating empty lists to record the predicted class and actual class of each audio file in the test set.
combined_preds = []
y_test_true=[]

# Here we combine all the sets of probabilites from each audio file to match their original audio file, and use these sets of probabilites to vote on the most likely class.
# We also regenerate y_test which contains the actual classes
for i in Test_index.ID.unique():
    probs = X_test_proba[Test_index[Test_index['ID']==i].index]
    test = y_test[Test_index[Test_index['ID']==i].index][0]
    total_probs=1
    for i in range(probs.shape[0]):
        total_probs = probs[i]*total_probs

    total_probs = total_probs.argmax()
    combined_preds.append(total_probs)
    y_test_true.append(test)

# We score how many of combined predictions are correct.
count = 0
for i in range(len(y_test_true)):
    if combined_preds[i]==y_test_true[i]:
        count +=1
LFCC_SVM_Score = count/len(y_test_true)
print(f'Final Accuracy Score: {LFCC_SVM_Score}')
# Out:
# Final Accuracy Score: 0.8174603174603174

# %% [markdown]
# ## RNN With Attention Layer

# %%
# From https://github.com/douglas125/SpeechCmdRecognition

def AttRNNSpeechModel(nCategories,
                      inputLength=None, rnn_func=L.LSTM):
    # simple LSTM

    inputs = L.Input(shape = inputLength, name='input')


    x = L.Conv2D(10, (5, 1), activation='relu', padding='same')(inputs)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(1, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)

    x = L.Lambda(lambda q: K.squeeze(q, -1), name='squeeze_last_dim')(x)

    x = L.Bidirectional(rnn_func(64, return_sequences=True,
                                 kernel_regularizer = L1L2(l1=0.01, l2=0.01))
                        )(x)  # [b_s, seq_len, vec_dim]
    x = L.Bidirectional(rnn_func(64, return_sequences=True, 
                                 kernel_regularizer = L1L2(l1=0.01, l2=0.01))
                        )(x)  # [b_s, seq_len, vec_dim]

    xFirst = L.Lambda(lambda q: q[:, -1])(x)  # [b_s, vec_dim]
    query = L.Dense(128)(xFirst)

    # dot product attention
    attScores = L.Dot(axes=[1, 2])([query, x])
    attScores = L.Softmax(name='attSoftmax')(attScores)  # [b_s, seq_len]

    # rescale sequence
    attVector = L.Dot(axes=[1, 1])([attScores, x])  # [b_s, vec_dim]

    x = L.Dense(64, activation='relu')(attVector)
    x = L.Dense(32)(x)

    output = L.Dense(nCategories, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs], outputs=[output])

    return model

# %% [markdown]
# ### MFCC RNN

# %%
# If a pretrained model exists, we'll load and compile that model. If not, we'll instantiate and compile a new model.
if os.path.exists(os.path.join(PATH,'Models/RNN_model_with_Attention_MFCC_chunks')):
    print('Pretrained model found')
    model=load_model(os.path.join(PATH,'Models/RNN_model_with_Attention_MFCC_chunks'))
    model.summary()
    train = 'no'
else:
    print('No model found, compiling new model')
    model = AttRNNSpeechModel(nCategories=7, inputLength = (MFCC_X_train.shape[1:4]))
    model.compile(optimizer='adam', loss=['sparse_categorical_crossentropy'], metrics=['sparse_categorical_accuracy'])
    model.summary()
    train = 'yes'
# Out:
# Pretrained model found
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 87, 80, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 87, 80, 10)   60          input[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 87, 80, 10)   40          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 87, 80, 1)    51          batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 87, 80, 1)    4           conv2d_1[0][0]
# __________________________________________________________________________________________________
# squeeze_last_dim (Lambda)       (None, 87, 80)       0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 87, 128)      74240       squeeze_last_dim[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 87, 128)      98816       bidirectional[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 128)          0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          16512       lambda[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 87)           0           dense[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# attSoftmax (Softmax)            (None, 87)           0           dot[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 128)          0           attSoftmax[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dot_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dense_1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 7)            231         dense_2[0][0]
# ==================================================================================================
# Total params: 200,290
# Trainable params: 200,268
# Non-trainable params: 22
# __________________________________________________________________________________________________

# %%
# # Uncomment this to continue training the loaded model
# train = 'yes'

# %%
# Training our model using EarlyStopping and ModelCheckpoints to save the best versions of our model.
if train == 'yes':  
    earlystopper = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=100,
                                 verbose=1, restore_best_weights=True)
    checkpointer = ModelCheckpoint('/Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks', 
                                   monitor='val_sparse_categorical_accuracy', 
                                   verbose=1, 
                                   save_best_only=True)


    history = model.fit(MFCC_X_train, y_train,
              epochs = 500,
              verbose = 1,
              validation_data=(MFCC_X_test, y_test),
              shuffle=True,
              callbacks=[earlystopper, checkpointer])
    model.save('/Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks')
# Out:
# Epoch 1/500
# 65/65 [==============================] - ETA: 0s - loss: 45.1670 - sparse_categorical_accuracy: 0.2262
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.13333, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# WARNING:tensorflow:From /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Classifying Emotions With Audio/Capstone_Project_Env/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 37s 562ms/step - loss: 45.1670 - sparse_categorical_accuracy: 0.2262 - val_loss: 20.5491 - val_sparse_categorical_accuracy: 0.1333
# Epoch 2/500
# 65/65 [==============================] - ETA: 0s - loss: 9.0519 - sparse_categorical_accuracy: 0.2721
# Epoch 00002: val_sparse_categorical_accuracy did not improve from 0.13333
# 65/65 [==============================] - 13s 194ms/step - loss: 9.0519 - sparse_categorical_accuracy: 0.2721 - val_loss: 3.1654 - val_sparse_categorical_accuracy: 0.1333
# Epoch 3/500
# 65/65 [==============================] - ETA: 0s - loss: 2.3532 - sparse_categorical_accuracy: 0.2735
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.13333 to 0.18333, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 493ms/step - loss: 2.3532 - sparse_categorical_accuracy: 0.2735 - val_loss: 2.2964 - val_sparse_categorical_accuracy: 0.1833
# Epoch 4/500
# 65/65 [==============================] - ETA: 0s - loss: 2.0511 - sparse_categorical_accuracy: 0.2947
# Epoch 00004: val_sparse_categorical_accuracy improved from 0.18333 to 0.19762, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 498ms/step - loss: 2.0511 - sparse_categorical_accuracy: 0.2947 - val_loss: 2.4964 - val_sparse_categorical_accuracy: 0.1976
# Epoch 5/500
# 65/65 [==============================] - ETA: 0s - loss: 2.0324 - sparse_categorical_accuracy: 0.2880
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.19762 to 0.27381, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 490ms/step - loss: 2.0324 - sparse_categorical_accuracy: 0.2880 - val_loss: 2.1311 - val_sparse_categorical_accuracy: 0.2738
# Epoch 6/500
# 65/65 [==============================] - ETA: 0s - loss: 2.0064 - sparse_categorical_accuracy: 0.2952
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.27381 to 0.32381, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 495ms/step - loss: 2.0064 - sparse_categorical_accuracy: 0.2952 - val_loss: 2.0060 - val_sparse_categorical_accuracy: 0.3238
# Epoch 7/500
# 65/65 [==============================] - ETA: 0s - loss: 1.8976 - sparse_categorical_accuracy: 0.3208
# Epoch 00007: val_sparse_categorical_accuracy improved from 0.32381 to 0.33095, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 492ms/step - loss: 1.8976 - sparse_categorical_accuracy: 0.3208 - val_loss: 1.8896 - val_sparse_categorical_accuracy: 0.3310
# Epoch 8/500
# 65/65 [==============================] - ETA: 0s - loss: 1.8761 - sparse_categorical_accuracy: 0.3261
# Epoch 00008: val_sparse_categorical_accuracy improved from 0.33095 to 0.35714, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 490ms/step - loss: 1.8761 - sparse_categorical_accuracy: 0.3261 - val_loss: 1.8578 - val_sparse_categorical_accuracy: 0.3571
# Epoch 9/500
# 65/65 [==============================] - ETA: 0s - loss: 1.8639 - sparse_categorical_accuracy: 0.3439
# Epoch 00009: val_sparse_categorical_accuracy improved from 0.35714 to 0.36548, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 491ms/step - loss: 1.8639 - sparse_categorical_accuracy: 0.3439 - val_loss: 1.8980 - val_sparse_categorical_accuracy: 0.3655
# Epoch 10/500
# 65/65 [==============================] - ETA: 0s - loss: 1.8699 - sparse_categorical_accuracy: 0.3454
# Epoch 00010: val_sparse_categorical_accuracy did not improve from 0.36548
# 65/65 [==============================] - 13s 193ms/step - loss: 1.8699 - sparse_categorical_accuracy: 0.3454 - val_loss: 1.9112 - val_sparse_categorical_accuracy: 0.3214
# Epoch 11/500
# 65/65 [==============================] - ETA: 0s - loss: 1.8636 - sparse_categorical_accuracy: 0.3685
# Epoch 00011: val_sparse_categorical_accuracy improved from 0.36548 to 0.37024, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 492ms/step - loss: 1.8636 - sparse_categorical_accuracy: 0.3685 - val_loss: 1.8155 - val_sparse_categorical_accuracy: 0.3702
# Epoch 12/500
# 65/65 [==============================] - ETA: 0s - loss: 1.8215 - sparse_categorical_accuracy: 0.3748
# Epoch 00012: val_sparse_categorical_accuracy did not improve from 0.37024
# 65/65 [==============================] - 13s 195ms/step - loss: 1.8215 - sparse_categorical_accuracy: 0.3748 - val_loss: 1.8124 - val_sparse_categorical_accuracy: 0.3476
# Epoch 13/500
# 65/65 [==============================] - ETA: 0s - loss: 1.8571 - sparse_categorical_accuracy: 0.3637
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.37024
# 65/65 [==============================] - 13s 197ms/step - loss: 1.8571 - sparse_categorical_accuracy: 0.3637 - val_loss: 1.7957 - val_sparse_categorical_accuracy: 0.3655
# Epoch 14/500
# 65/65 [==============================] - ETA: 0s - loss: 1.8490 - sparse_categorical_accuracy: 0.3743
# Epoch 00014: val_sparse_categorical_accuracy improved from 0.37024 to 0.39405, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 31s 483ms/step - loss: 1.8490 - sparse_categorical_accuracy: 0.3743 - val_loss: 1.9201 - val_sparse_categorical_accuracy: 0.3940
# Epoch 15/500
# 65/65 [==============================] - ETA: 0s - loss: 1.8799 - sparse_categorical_accuracy: 0.3714
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.39405
# 65/65 [==============================] - 13s 195ms/step - loss: 1.8799 - sparse_categorical_accuracy: 0.3714 - val_loss: 2.0522 - val_sparse_categorical_accuracy: 0.3024
# Epoch 16/500
# 65/65 [==============================] - ETA: 0s - loss: 1.8292 - sparse_categorical_accuracy: 0.3985
# Epoch 00016: val_sparse_categorical_accuracy improved from 0.39405 to 0.42500, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 487ms/step - loss: 1.8292 - sparse_categorical_accuracy: 0.3985 - val_loss: 1.7485 - val_sparse_categorical_accuracy: 0.4250
# Epoch 17/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7802 - sparse_categorical_accuracy: 0.3956
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.42500
# 65/65 [==============================] - 13s 194ms/step - loss: 1.7802 - sparse_categorical_accuracy: 0.3956 - val_loss: 1.7920 - val_sparse_categorical_accuracy: 0.3762
# Epoch 18/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7800 - sparse_categorical_accuracy: 0.4042
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.42500
# 65/65 [==============================] - 13s 194ms/step - loss: 1.7800 - sparse_categorical_accuracy: 0.4042 - val_loss: 1.8161 - val_sparse_categorical_accuracy: 0.4131
# Epoch 19/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7818 - sparse_categorical_accuracy: 0.4206
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.42500
# 65/65 [==============================] - 13s 195ms/step - loss: 1.7818 - sparse_categorical_accuracy: 0.4206 - val_loss: 1.7946 - val_sparse_categorical_accuracy: 0.4155
# Epoch 20/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7858 - sparse_categorical_accuracy: 0.4216
# Epoch 00020: val_sparse_categorical_accuracy improved from 0.42500 to 0.42857, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 489ms/step - loss: 1.7858 - sparse_categorical_accuracy: 0.4216 - val_loss: 1.8106 - val_sparse_categorical_accuracy: 0.4286
# Epoch 21/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7352 - sparse_categorical_accuracy: 0.4414
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.42857
# 65/65 [==============================] - 13s 195ms/step - loss: 1.7352 - sparse_categorical_accuracy: 0.4414 - val_loss: 1.7431 - val_sparse_categorical_accuracy: 0.4226
# Epoch 22/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7231 - sparse_categorical_accuracy: 0.4563
# Epoch 00022: val_sparse_categorical_accuracy improved from 0.42857 to 0.43690, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 31s 482ms/step - loss: 1.7231 - sparse_categorical_accuracy: 0.4563 - val_loss: 1.7373 - val_sparse_categorical_accuracy: 0.4369
# Epoch 23/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7920 - sparse_categorical_accuracy: 0.4202
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.43690
# 65/65 [==============================] - 13s 196ms/step - loss: 1.7920 - sparse_categorical_accuracy: 0.4202 - val_loss: 2.1025 - val_sparse_categorical_accuracy: 0.4286
# Epoch 24/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7870 - sparse_categorical_accuracy: 0.4544
# Epoch 00024: val_sparse_categorical_accuracy improved from 0.43690 to 0.45714, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 31s 482ms/step - loss: 1.7870 - sparse_categorical_accuracy: 0.4544 - val_loss: 1.7333 - val_sparse_categorical_accuracy: 0.4571
# Epoch 25/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6821 - sparse_categorical_accuracy: 0.4867
# Epoch 00025: val_sparse_categorical_accuracy improved from 0.45714 to 0.48810, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 487ms/step - loss: 1.6821 - sparse_categorical_accuracy: 0.4867 - val_loss: 1.6983 - val_sparse_categorical_accuracy: 0.4881
# Epoch 26/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6692 - sparse_categorical_accuracy: 0.5002
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.48810
# 65/65 [==============================] - 12s 192ms/step - loss: 1.6692 - sparse_categorical_accuracy: 0.5002 - val_loss: 1.9413 - val_sparse_categorical_accuracy: 0.4107
# Epoch 27/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7366 - sparse_categorical_accuracy: 0.4732
# Epoch 00027: val_sparse_categorical_accuracy improved from 0.48810 to 0.49048, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 487ms/step - loss: 1.7366 - sparse_categorical_accuracy: 0.4732 - val_loss: 1.6821 - val_sparse_categorical_accuracy: 0.4905
# Epoch 28/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6720 - sparse_categorical_accuracy: 0.4916
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.49048
# 65/65 [==============================] - 12s 192ms/step - loss: 1.6720 - sparse_categorical_accuracy: 0.4916 - val_loss: 1.7627 - val_sparse_categorical_accuracy: 0.4619
# Epoch 29/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7713 - sparse_categorical_accuracy: 0.4723
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.49048
# 65/65 [==============================] - 12s 190ms/step - loss: 1.7713 - sparse_categorical_accuracy: 0.4723 - val_loss: 1.7991 - val_sparse_categorical_accuracy: 0.4560
# Epoch 30/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6708 - sparse_categorical_accuracy: 0.5031
# Epoch 00030: val_sparse_categorical_accuracy did not improve from 0.49048
# 65/65 [==============================] - 13s 198ms/step - loss: 1.6708 - sparse_categorical_accuracy: 0.5031 - val_loss: 1.7858 - val_sparse_categorical_accuracy: 0.4690
# Epoch 31/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5901 - sparse_categorical_accuracy: 0.5162
# Epoch 00031: val_sparse_categorical_accuracy improved from 0.49048 to 0.50476, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 500ms/step - loss: 1.5901 - sparse_categorical_accuracy: 0.5162 - val_loss: 1.6775 - val_sparse_categorical_accuracy: 0.5048
# Epoch 32/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6395 - sparse_categorical_accuracy: 0.5137
# Epoch 00032: val_sparse_categorical_accuracy did not improve from 0.50476
# 65/65 [==============================] - 13s 198ms/step - loss: 1.6395 - sparse_categorical_accuracy: 0.5137 - val_loss: 1.7250 - val_sparse_categorical_accuracy: 0.4976
# Epoch 33/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6407 - sparse_categorical_accuracy: 0.5142
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.50476
# 65/65 [==============================] - 13s 199ms/step - loss: 1.6407 - sparse_categorical_accuracy: 0.5142 - val_loss: 1.7694 - val_sparse_categorical_accuracy: 0.4726
# Epoch 34/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6074 - sparse_categorical_accuracy: 0.5301
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.50476
# 65/65 [==============================] - 13s 197ms/step - loss: 1.6074 - sparse_categorical_accuracy: 0.5301 - val_loss: 1.7964 - val_sparse_categorical_accuracy: 0.4774
# Epoch 35/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6762 - sparse_categorical_accuracy: 0.5273
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.50476
# 65/65 [==============================] - 13s 199ms/step - loss: 1.6762 - sparse_categorical_accuracy: 0.5273 - val_loss: 1.8394 - val_sparse_categorical_accuracy: 0.4905
# Epoch 36/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6707 - sparse_categorical_accuracy: 0.5210
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.50476
# 65/65 [==============================] - 13s 200ms/step - loss: 1.6707 - sparse_categorical_accuracy: 0.5210 - val_loss: 1.7448 - val_sparse_categorical_accuracy: 0.4810
# Epoch 37/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6033 - sparse_categorical_accuracy: 0.5350
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.50476
# 65/65 [==============================] - 13s 199ms/step - loss: 1.6033 - sparse_categorical_accuracy: 0.5350 - val_loss: 1.7329 - val_sparse_categorical_accuracy: 0.5012
# Epoch 38/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5958 - sparse_categorical_accuracy: 0.5301
# Epoch 00038: val_sparse_categorical_accuracy improved from 0.50476 to 0.52024, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 499ms/step - loss: 1.5958 - sparse_categorical_accuracy: 0.5301 - val_loss: 1.7041 - val_sparse_categorical_accuracy: 0.5202
# Epoch 39/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5927 - sparse_categorical_accuracy: 0.5432
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.52024
# 65/65 [==============================] - 13s 196ms/step - loss: 1.5927 - sparse_categorical_accuracy: 0.5432 - val_loss: 1.8421 - val_sparse_categorical_accuracy: 0.4738
# Epoch 40/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5807 - sparse_categorical_accuracy: 0.5538
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.52024
# 65/65 [==============================] - 13s 197ms/step - loss: 1.5807 - sparse_categorical_accuracy: 0.5538 - val_loss: 1.7616 - val_sparse_categorical_accuracy: 0.4845
# Epoch 41/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5925 - sparse_categorical_accuracy: 0.5393
# Epoch 00041: val_sparse_categorical_accuracy improved from 0.52024 to 0.52381, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 32s 494ms/step - loss: 1.5925 - sparse_categorical_accuracy: 0.5393 - val_loss: 1.7021 - val_sparse_categorical_accuracy: 0.5238
# Epoch 42/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5274 - sparse_categorical_accuracy: 0.5702
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.52381
# 65/65 [==============================] - 13s 198ms/step - loss: 1.5274 - sparse_categorical_accuracy: 0.5702 - val_loss: 1.7713 - val_sparse_categorical_accuracy: 0.4976
# Epoch 43/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7831 - sparse_categorical_accuracy: 0.5292
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.52381
# 65/65 [==============================] - 13s 197ms/step - loss: 1.7831 - sparse_categorical_accuracy: 0.5292 - val_loss: 1.9786 - val_sparse_categorical_accuracy: 0.4940
# Epoch 44/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6100 - sparse_categorical_accuracy: 0.5639
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.52381
# 65/65 [==============================] - 13s 203ms/step - loss: 1.6100 - sparse_categorical_accuracy: 0.5639 - val_loss: 1.7431 - val_sparse_categorical_accuracy: 0.5024
# Epoch 45/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5924 - sparse_categorical_accuracy: 0.5514
# Epoch 00045: val_sparse_categorical_accuracy improved from 0.52381 to 0.52738, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 33s 502ms/step - loss: 1.5924 - sparse_categorical_accuracy: 0.5514 - val_loss: 1.7123 - val_sparse_categorical_accuracy: 0.5274
# Epoch 46/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5687 - sparse_categorical_accuracy: 0.5610
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 13s 200ms/step - loss: 1.5687 - sparse_categorical_accuracy: 0.5610 - val_loss: 1.7444 - val_sparse_categorical_accuracy: 0.5262
# Epoch 47/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5209 - sparse_categorical_accuracy: 0.5774
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 14s 209ms/step - loss: 1.5209 - sparse_categorical_accuracy: 0.5774 - val_loss: 1.7451 - val_sparse_categorical_accuracy: 0.5071
# Epoch 48/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5104 - sparse_categorical_accuracy: 0.5731
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 13s 206ms/step - loss: 1.5104 - sparse_categorical_accuracy: 0.5731 - val_loss: 1.9244 - val_sparse_categorical_accuracy: 0.4595
# Epoch 49/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6344 - sparse_categorical_accuracy: 0.5538
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 14s 210ms/step - loss: 1.6344 - sparse_categorical_accuracy: 0.5538 - val_loss: 1.7568 - val_sparse_categorical_accuracy: 0.5000
# Epoch 50/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5081 - sparse_categorical_accuracy: 0.5938
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 14s 211ms/step - loss: 1.5081 - sparse_categorical_accuracy: 0.5938 - val_loss: 1.7242 - val_sparse_categorical_accuracy: 0.5131
# Epoch 51/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5180 - sparse_categorical_accuracy: 0.5803
# Epoch 00051: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 14s 212ms/step - loss: 1.5180 - sparse_categorical_accuracy: 0.5803 - val_loss: 1.8494 - val_sparse_categorical_accuracy: 0.5000
# Epoch 52/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5093 - sparse_categorical_accuracy: 0.5871
# Epoch 00052: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 14s 215ms/step - loss: 1.5093 - sparse_categorical_accuracy: 0.5871 - val_loss: 1.8668 - val_sparse_categorical_accuracy: 0.5155
# Epoch 53/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5052 - sparse_categorical_accuracy: 0.5861
# Epoch 00053: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 14s 216ms/step - loss: 1.5052 - sparse_categorical_accuracy: 0.5861 - val_loss: 1.8083 - val_sparse_categorical_accuracy: 0.4988
# Epoch 54/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5539 - sparse_categorical_accuracy: 0.5914
# Epoch 00054: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 14s 221ms/step - loss: 1.5539 - sparse_categorical_accuracy: 0.5914 - val_loss: 1.9502 - val_sparse_categorical_accuracy: 0.4952
# Epoch 55/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5161 - sparse_categorical_accuracy: 0.5885
# Epoch 00055: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 14s 218ms/step - loss: 1.5161 - sparse_categorical_accuracy: 0.5885 - val_loss: 1.6542 - val_sparse_categorical_accuracy: 0.5179
# Epoch 56/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4512 - sparse_categorical_accuracy: 0.6083
# Epoch 00056: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 14s 219ms/step - loss: 1.4512 - sparse_categorical_accuracy: 0.6083 - val_loss: 1.7589 - val_sparse_categorical_accuracy: 0.5250
# Epoch 57/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5342 - sparse_categorical_accuracy: 0.6083
# Epoch 00057: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 14s 219ms/step - loss: 1.5342 - sparse_categorical_accuracy: 0.6083 - val_loss: 2.3103 - val_sparse_categorical_accuracy: 0.5024
# Epoch 58/500
# 65/65 [==============================] - ETA: 0s - loss: 1.9251 - sparse_categorical_accuracy: 0.5789
# Epoch 00058: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 15s 223ms/step - loss: 1.9251 - sparse_categorical_accuracy: 0.5789 - val_loss: 1.8835 - val_sparse_categorical_accuracy: 0.5226
# Epoch 59/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5397 - sparse_categorical_accuracy: 0.6189
# Epoch 00059: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 14s 219ms/step - loss: 1.5397 - sparse_categorical_accuracy: 0.6189 - val_loss: 1.8219 - val_sparse_categorical_accuracy: 0.5095
# Epoch 60/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5225 - sparse_categorical_accuracy: 0.6102
# Epoch 00060: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 14s 217ms/step - loss: 1.5225 - sparse_categorical_accuracy: 0.6102 - val_loss: 1.7739 - val_sparse_categorical_accuracy: 0.5226
# Epoch 61/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4855 - sparse_categorical_accuracy: 0.6155
# Epoch 00061: val_sparse_categorical_accuracy did not improve from 0.52738
# 65/65 [==============================] - 14s 218ms/step - loss: 1.4855 - sparse_categorical_accuracy: 0.6155 - val_loss: 1.9236 - val_sparse_categorical_accuracy: 0.4905
# Epoch 62/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5268 - sparse_categorical_accuracy: 0.6112
# Epoch 00062: val_sparse_categorical_accuracy improved from 0.52738 to 0.54048, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 34s 522ms/step - loss: 1.5268 - sparse_categorical_accuracy: 0.6112 - val_loss: 1.7440 - val_sparse_categorical_accuracy: 0.5405
# Epoch 63/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4338 - sparse_categorical_accuracy: 0.6343
# Epoch 00063: val_sparse_categorical_accuracy did not improve from 0.54048
# 65/65 [==============================] - 14s 215ms/step - loss: 1.4338 - sparse_categorical_accuracy: 0.6343 - val_loss: 1.7171 - val_sparse_categorical_accuracy: 0.5310
# Epoch 64/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4918 - sparse_categorical_accuracy: 0.6151
# Epoch 00064: val_sparse_categorical_accuracy improved from 0.54048 to 0.54167, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 33s 514ms/step - loss: 1.4918 - sparse_categorical_accuracy: 0.6151 - val_loss: 1.8267 - val_sparse_categorical_accuracy: 0.5417
# Epoch 65/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4739 - sparse_categorical_accuracy: 0.6257
# Epoch 00065: val_sparse_categorical_accuracy did not improve from 0.54167
# 65/65 [==============================] - 13s 204ms/step - loss: 1.4739 - sparse_categorical_accuracy: 0.6257 - val_loss: 1.8325 - val_sparse_categorical_accuracy: 0.5119
# Epoch 66/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4753 - sparse_categorical_accuracy: 0.6141
# Epoch 00066: val_sparse_categorical_accuracy did not improve from 0.54167
# 65/65 [==============================] - 13s 206ms/step - loss: 1.4753 - sparse_categorical_accuracy: 0.6141 - val_loss: 1.8158 - val_sparse_categorical_accuracy: 0.5286
# Epoch 67/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4378 - sparse_categorical_accuracy: 0.6329
# Epoch 00067: val_sparse_categorical_accuracy did not improve from 0.54167
# 65/65 [==============================] - 13s 204ms/step - loss: 1.4378 - sparse_categorical_accuracy: 0.6329 - val_loss: 1.7909 - val_sparse_categorical_accuracy: 0.5405
# Epoch 68/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4497 - sparse_categorical_accuracy: 0.6300
# Epoch 00068: val_sparse_categorical_accuracy did not improve from 0.54167
# 65/65 [==============================] - 13s 202ms/step - loss: 1.4497 - sparse_categorical_accuracy: 0.6300 - val_loss: 1.8884 - val_sparse_categorical_accuracy: 0.5345
# Epoch 69/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5068 - sparse_categorical_accuracy: 0.6170
# Epoch 00069: val_sparse_categorical_accuracy improved from 0.54167 to 0.54762, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 34s 522ms/step - loss: 1.5068 - sparse_categorical_accuracy: 0.6170 - val_loss: 1.7443 - val_sparse_categorical_accuracy: 0.5476
# Epoch 70/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4192 - sparse_categorical_accuracy: 0.6435
# Epoch 00070: val_sparse_categorical_accuracy did not improve from 0.54762
# 65/65 [==============================] - 13s 201ms/step - loss: 1.4192 - sparse_categorical_accuracy: 0.6435 - val_loss: 1.7947 - val_sparse_categorical_accuracy: 0.5274
# Epoch 71/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4067 - sparse_categorical_accuracy: 0.6575
# Epoch 00071: val_sparse_categorical_accuracy did not improve from 0.54762
# 65/65 [==============================] - 14s 210ms/step - loss: 1.4067 - sparse_categorical_accuracy: 0.6575 - val_loss: 1.8418 - val_sparse_categorical_accuracy: 0.5345
# Epoch 72/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3782 - sparse_categorical_accuracy: 0.6503
# Epoch 00072: val_sparse_categorical_accuracy improved from 0.54762 to 0.55476, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 33s 510ms/step - loss: 1.3782 - sparse_categorical_accuracy: 0.6503 - val_loss: 1.8300 - val_sparse_categorical_accuracy: 0.5548
# Epoch 73/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4130 - sparse_categorical_accuracy: 0.6541
# Epoch 00073: val_sparse_categorical_accuracy did not improve from 0.55476
# 65/65 [==============================] - 73s 1s/step - loss: 1.4130 - sparse_categorical_accuracy: 0.6541 - val_loss: 2.0101 - val_sparse_categorical_accuracy: 0.5250
# Epoch 74/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5339 - sparse_categorical_accuracy: 0.6474
# Epoch 00074: val_sparse_categorical_accuracy did not improve from 0.55476
# 65/65 [==============================] - 13s 204ms/step - loss: 1.5339 - sparse_categorical_accuracy: 0.6474 - val_loss: 1.8270 - val_sparse_categorical_accuracy: 0.5357
# Epoch 75/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4642 - sparse_categorical_accuracy: 0.6397
# Epoch 00075: val_sparse_categorical_accuracy did not improve from 0.55476
# 65/65 [==============================] - 13s 204ms/step - loss: 1.4642 - sparse_categorical_accuracy: 0.6397 - val_loss: 1.9057 - val_sparse_categorical_accuracy: 0.5333
# Epoch 76/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4654 - sparse_categorical_accuracy: 0.6488
# Epoch 00076: val_sparse_categorical_accuracy did not improve from 0.55476
# 65/65 [==============================] - 14s 221ms/step - loss: 1.4654 - sparse_categorical_accuracy: 0.6488 - val_loss: 1.8724 - val_sparse_categorical_accuracy: 0.5333
# Epoch 77/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3881 - sparse_categorical_accuracy: 0.6565
# Epoch 00077: val_sparse_categorical_accuracy did not improve from 0.55476
# 65/65 [==============================] - 13s 207ms/step - loss: 1.3881 - sparse_categorical_accuracy: 0.6565 - val_loss: 1.9356 - val_sparse_categorical_accuracy: 0.5274
# Epoch 78/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4140 - sparse_categorical_accuracy: 0.6705
# Epoch 00078: val_sparse_categorical_accuracy did not improve from 0.55476
# 65/65 [==============================] - 14s 209ms/step - loss: 1.4140 - sparse_categorical_accuracy: 0.6705 - val_loss: 2.1627 - val_sparse_categorical_accuracy: 0.5107
# Epoch 79/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4424 - sparse_categorical_accuracy: 0.6725
# Epoch 00079: val_sparse_categorical_accuracy improved from 0.55476 to 0.55833, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets
# 65/65 [==============================] - 33s 507ms/step - loss: 1.4424 - sparse_categorical_accuracy: 0.6725 - val_loss: 1.9092 - val_sparse_categorical_accuracy: 0.5583
# Epoch 80/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3881 - sparse_categorical_accuracy: 0.6749
# Epoch 00080: val_sparse_categorical_accuracy did not improve from 0.55833
# 65/65 [==============================] - 13s 201ms/step - loss: 1.3881 - sparse_categorical_accuracy: 0.6749 - val_loss: 1.8986 - val_sparse_categorical_accuracy: 0.5393
# Epoch 81/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4787 - sparse_categorical_accuracy: 0.6585
# Epoch 00081: val_sparse_categorical_accuracy did not improve from 0.55833
# 65/65 [==============================] - 14s 211ms/step - loss: 1.4787 - sparse_categorical_accuracy: 0.6585 - val_loss: 2.0718 - val_sparse_categorical_accuracy: 0.5167
# Epoch 82/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4392 - sparse_categorical_accuracy: 0.6638
# Epoch 00082: val_sparse_categorical_accuracy did not improve from 0.55833
# 65/65 [==============================] - 14s 208ms/step - loss: 1.4392 - sparse_categorical_accuracy: 0.6638 - val_loss: 1.9998 - val_sparse_categorical_accuracy: 0.5393
# Epoch 83/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3748 - sparse_categorical_accuracy: 0.6816
# Epoch 00083: val_sparse_categorical_accuracy did not improve from 0.55833
# 65/65 [==============================] - 14s 210ms/step - loss: 1.3748 - sparse_categorical_accuracy: 0.6816 - val_loss: 1.9085 - val_sparse_categorical_accuracy: 0.5405
# Epoch 84/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3505 - sparse_categorical_accuracy: 0.6879
# Epoch 00084: val_sparse_categorical_accuracy did not improve from 0.55833
# 65/65 [==============================] - 14s 209ms/step - loss: 1.3505 - sparse_categorical_accuracy: 0.6879 - val_loss: 1.8635 - val_sparse_categorical_accuracy: 0.5429
# Epoch 85/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3372 - sparse_categorical_accuracy: 0.7038
# Epoch 00085: val_sparse_categorical_accuracy did not improve from 0.55833
# 65/65 [==============================] - 14s
val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 14s 210ms/step - loss: 0.3529 - sparse_categorical_accuracy: 0.9937 - val_loss: 2.9484 - val_sparse_categorical_accuracy: 0.5750
# Epoch 493/500
# 65/65 [==============================] - ETA: 0s - loss: 0.3244 - sparse_categorical_accuracy: 0.9947
# Epoch 00493: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 13s 207ms/step - loss: 0.3244 - sparse_categorical_accuracy: 0.9947 - val_loss: 2.9516 - val_sparse_categorical_accuracy: 0.5774
# Epoch 494/500
# 65/65 [==============================] - ETA: 0s - loss: 0.3215 - sparse_categorical_accuracy: 0.9947
# Epoch 00494: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 14s 209ms/step - loss: 0.3215 - sparse_categorical_accuracy: 0.9947 - val_loss: 2.9414 - val_sparse_categorical_accuracy: 0.5810
# Epoch 495/500
# 65/65 [==============================] - ETA: 0s - loss: 0.3246 - sparse_categorical_accuracy: 0.9952
# Epoch 00495: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 14s 208ms/step - loss: 0.3246 - sparse_categorical_accuracy: 0.9952 - val_loss: 3.0214 - val_sparse_categorical_accuracy: 0.5738
# Epoch 496/500
# 65/65 [==============================] - ETA: 0s - loss: 0.3315 - sparse_categorical_accuracy: 0.9928
# Epoch 00496: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 13s 207ms/step - loss: 0.3315 - sparse_categorical_accuracy: 0.9928 - val_loss: 3.0575 - val_sparse_categorical_accuracy: 0.5631
# Epoch 497/500
# 65/65 [==============================] - ETA: 0s - loss: 0.5565 - sparse_categorical_accuracy: 0.9638
# Epoch 00497: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 13s 206ms/step - loss: 0.5565 - sparse_categorical_accuracy: 0.9638 - val_loss: 3.7806 - val_sparse_categorical_accuracy: 0.5583
# Epoch 498/500
# 65/65 [==============================] - ETA: 0s - loss: 2.1925 - sparse_categorical_accuracy: 0.7791
# Epoch 00498: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 14s 214ms/step - loss: 2.1925 - sparse_categorical_accuracy: 0.7791 - val_loss: 4.0574 - val_sparse_categorical_accuracy: 0.5131
# Epoch 499/500
# 65/65 [==============================] - ETA: 0s - loss: 1.9434 - sparse_categorical_accuracy: 0.7887
# Epoch 00499: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 14s 208ms/step - loss: 1.9434 - sparse_categorical_accuracy: 0.7887 - val_loss: 2.7720 - val_sparse_categorical_accuracy: 0.5655
# Epoch 500/500
# 65/65 [==============================] - ETA: 0s - loss: 0.8427 - sparse_categorical_accuracy: 0.9402
# Epoch 00500: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 14s 219ms/step - loss: 0.8427 - sparse_categorical_accuracy: 0.9402 - val_loss: 2.4821 - val_sparse_categorical_accuracy: 0.5667
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_MFCC_chunks/assets

# %%
# This will combine the predictions of every 1 second chunk of audio from each audiofile. This is done through multiplicative probabilistic voting.
# This functions in the same way as the code used to combine prediction probabilities for the SVM.
X_test_proba = model.predict(MFCC_X_test)

combined_preds = []
y_test_true=[]
for i in Test_index.ID.unique():
    probs = X_test_proba[Test_index[Test_index['ID']==i].index]
    test = y_test[Test_index[Test_index['ID']==i].index][0]
    total_probs=1
    for i in range(probs.shape[0]):
        total_probs = probs[i]*total_probs

    total_probs = total_probs.argmax()
    combined_preds.append(total_probs)
    y_test_true.append(test)

count = 0
for i in range(len(y_test_true)):
    if combined_preds[i]==y_test_true[i]:
        count +=1
MFCC_RNN_score = count/len(y_test_true)

print(f'Final Accuracy Score: {MFCC_RNN_score}')
# Out:
# Final Accuracy Score: 0.7976190476190477

# %% [markdown]
# ### GFCC RNN

# %%
# If a pretrained model exists, we'll load and compile that model. If not, we'll instantiate and compile a new model.
if os.path.exists(os.path.join(PATH,'Models/RNN_model_with_Attention_GFCC_chunks')):
    print('Pretrained model found')
    model=load_model(os.path.join(PATH,'Models/RNN_model_with_Attention_GFCC_chunks'))
    model.summary()
    train = 'no'
else:
    print('No model found, compiling new model')
    model = AttRNNSpeechModel(nCategories=7, inputLength = (GFCC_X_train.shape[1:4]))
    model.compile(optimizer='adam', loss=['sparse_categorical_crossentropy'], metrics=['sparse_categorical_accuracy'])
    model.summary()
    train = 'yes'
# Out:
# Pretrained model found
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 87, 80, 1)]  0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 87, 80, 10)   60          input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 87, 80, 10)   40          conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 87, 80, 1)    51          batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 87, 80, 1)    4           conv2d_3[0][0]
# __________________________________________________________________________________________________
# squeeze_last_dim (Lambda)       (None, 87, 80)       0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 87, 128)      74240       squeeze_last_dim[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 87, 128)      98816       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 128)          0           bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          16512       lambda_1[0][0]
# __________________________________________________________________________________________________
# dot_2 (Dot)                     (None, 87)           0           dense_3[0][0]
#                                                                  bidirectional_3[0][0]
# __________________________________________________________________________________________________
# attSoftmax (Softmax)            (None, 87)           0           dot_2[0][0]
# __________________________________________________________________________________________________
# dot_3 (Dot)                     (None, 128)          0           attSoftmax[0][0]
#                                                                  bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           8256        dot_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 32)           2080        dense_4[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 7)            231         dense_5[0][0]
# ==================================================================================================
# Total params: 200,290
# Trainable params: 200,268
# Non-trainable params: 22
# __________________________________________________________________________________________________

# %%
# # Uncomment this to continue training the loaded model
# train = 'yes'

# %%
if train == 'yes':   
    earlystopper = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=100,
                                 verbose=1, restore_best_weights=True)
    checkpointer = ModelCheckpoint('/Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks', 
                                   monitor='val_sparse_categorical_accuracy', 
                                   verbose=1, 
                                   save_best_only=True)


    model.fit(GFCC_X_train, y_train,
              epochs = 500,
              verbose = 1,
              validation_data=(GFCC_X_test, y_test),
              shuffle=True,
              callbacks=[earlystopper, checkpointer])
    model.save('/Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks')
# Out:
# Epoch 1/500
# 65/65 [==============================] - ETA: 0s - loss: 45.1898 - sparse_categorical_accuracy: 0.2586
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.33929, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 31s 482ms/step - loss: 45.1898 - sparse_categorical_accuracy: 0.2586 - val_loss: 20.3337 - val_sparse_categorical_accuracy: 0.3393
# Epoch 2/500
# 65/65 [==============================] - ETA: 0s - loss: 9.0606 - sparse_categorical_accuracy: 0.3690
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.33929 to 0.38095, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 32s 485ms/step - loss: 9.0606 - sparse_categorical_accuracy: 0.3690 - val_loss: 2.8735 - val_sparse_categorical_accuracy: 0.3810
# Epoch 3/500
# 65/65 [==============================] - ETA: 0s - loss: 2.2732 - sparse_categorical_accuracy: 0.3994
# Epoch 00003: val_sparse_categorical_accuracy did not improve from 0.38095
# 65/65 [==============================] - 13s 193ms/step - loss: 2.2732 - sparse_categorical_accuracy: 0.3994 - val_loss: 2.1491 - val_sparse_categorical_accuracy: 0.3702
# Epoch 4/500
# 65/65 [==============================] - ETA: 0s - loss: 1.9813 - sparse_categorical_accuracy: 0.4260
# Epoch 00004: val_sparse_categorical_accuracy improved from 0.38095 to 0.42262, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 31s 475ms/step - loss: 1.9813 - sparse_categorical_accuracy: 0.4260 - val_loss: 2.0127 - val_sparse_categorical_accuracy: 0.4226
# Epoch 5/500
# 65/65 [==============================] - ETA: 0s - loss: 1.8666 - sparse_categorical_accuracy: 0.4592
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.42262 to 0.43810, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 31s 474ms/step - loss: 1.8666 - sparse_categorical_accuracy: 0.4592 - val_loss: 1.9851 - val_sparse_categorical_accuracy: 0.4381
# Epoch 6/500
# 65/65 [==============================] - ETA: 0s - loss: 1.9381 - sparse_categorical_accuracy: 0.4549
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.43810 to 0.44286, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 31s 479ms/step - loss: 1.9381 - sparse_categorical_accuracy: 0.4549 - val_loss: 1.9385 - val_sparse_categorical_accuracy: 0.4429
# Epoch 7/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7831 - sparse_categorical_accuracy: 0.4809
# Epoch 00007: val_sparse_categorical_accuracy improved from 0.44286 to 0.45119, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 31s 477ms/step - loss: 1.7831 - sparse_categorical_accuracy: 0.4809 - val_loss: 1.8364 - val_sparse_categorical_accuracy: 0.4512
# Epoch 8/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7247 - sparse_categorical_accuracy: 0.5012
# Epoch 00008: val_sparse_categorical_accuracy improved from 0.45119 to 0.48929, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 30s 469ms/step - loss: 1.7247 - sparse_categorical_accuracy: 0.5012 - val_loss: 1.8338 - val_sparse_categorical_accuracy: 0.4893
# Epoch 9/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7557 - sparse_categorical_accuracy: 0.5022
# Epoch 00009: val_sparse_categorical_accuracy did not improve from 0.48929
# 65/65 [==============================] - 12s 192ms/step - loss: 1.7557 - sparse_categorical_accuracy: 0.5022 - val_loss: 1.8451 - val_sparse_categorical_accuracy: 0.4702
# Epoch 10/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7115 - sparse_categorical_accuracy: 0.5490
# Epoch 00010: val_sparse_categorical_accuracy improved from 0.48929 to 0.49643, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 31s 482ms/step - loss: 1.7115 - sparse_categorical_accuracy: 0.5490 - val_loss: 1.8257 - val_sparse_categorical_accuracy: 0.4964
# Epoch 11/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6887 - sparse_categorical_accuracy: 0.5219
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.49643
# 65/65 [==============================] - 13s 195ms/step - loss: 1.6887 - sparse_categorical_accuracy: 0.5219 - val_loss: 1.7973 - val_sparse_categorical_accuracy: 0.4940
# Epoch 12/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7276 - sparse_categorical_accuracy: 0.5292
# Epoch 00012: val_sparse_categorical_accuracy improved from 0.49643 to 0.52024, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 30s 467ms/step - loss: 1.7276 - sparse_categorical_accuracy: 0.5292 - val_loss: 1.7190 - val_sparse_categorical_accuracy: 0.5202
# Epoch 13/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6108 - sparse_categorical_accuracy: 0.5509
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.52024
# 65/65 [==============================] - 14s 215ms/step - loss: 1.6108 - sparse_categorical_accuracy: 0.5509 - val_loss: 1.7442 - val_sparse_categorical_accuracy: 0.4976
# Epoch 14/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6570 - sparse_categorical_accuracy: 0.5509
# Epoch 00014: val_sparse_categorical_accuracy improved from 0.52024 to 0.53095, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 30s 466ms/step - loss: 1.6570 - sparse_categorical_accuracy: 0.5509 - val_loss: 1.8575 - val_sparse_categorical_accuracy: 0.5310
# Epoch 15/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6748 - sparse_categorical_accuracy: 0.5485
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.53095
# 65/65 [==============================] - 13s 193ms/step - loss: 1.6748 - sparse_categorical_accuracy: 0.5485 - val_loss: 1.7008 - val_sparse_categorical_accuracy: 0.5262
# Epoch 16/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5640 - sparse_categorical_accuracy: 0.5702
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.53095
# 65/65 [==============================] - 13s 195ms/step - loss: 1.5640 - sparse_categorical_accuracy: 0.5702 - val_loss: 1.7378 - val_sparse_categorical_accuracy: 0.5071
# Epoch 17/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5399 - sparse_categorical_accuracy: 0.5822
# Epoch 00017: val_sparse_categorical_accuracy improved from 0.53095 to 0.53452, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 35s 534ms/step - loss: 1.5399 - sparse_categorical_accuracy: 0.5822 - val_loss: 1.7610 - val_sparse_categorical_accuracy: 0.5345
# Epoch 18/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6371 - sparse_categorical_accuracy: 0.5745
# Epoch 00018: val_sparse_categorical_accuracy improved from 0.53452 to 0.55357, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 32s 497ms/step - loss: 1.6371 - sparse_categorical_accuracy: 0.5745 - val_loss: 1.7498 - val_sparse_categorical_accuracy: 0.5536
# Epoch 19/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5532 - sparse_categorical_accuracy: 0.5769
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.55357
# 65/65 [==============================] - 13s 201ms/step - loss: 1.5532 - sparse_categorical_accuracy: 0.5769 - val_loss: 1.7766 - val_sparse_categorical_accuracy: 0.5440
# Epoch 20/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5886 - sparse_categorical_accuracy: 0.5890
# Epoch 00020: val_sparse_categorical_accuracy improved from 0.55357 to 0.55476, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 32s 485ms/step - loss: 1.5886 - sparse_categorical_accuracy: 0.5890 - val_loss: 1.7015 - val_sparse_categorical_accuracy: 0.5548
# Epoch 21/500
# 65/65 [==============================] - ETA: 0s - loss: 1.9995 - sparse_categorical_accuracy: 0.5538
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.55476
# 65/65 [==============================] - 13s 197ms/step - loss: 1.9995 - sparse_categorical_accuracy: 0.5538 - val_loss: 2.0718 - val_sparse_categorical_accuracy: 0.4917
# Epoch 22/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6711 - sparse_categorical_accuracy: 0.5924
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.55476
# 65/65 [==============================] - 13s 195ms/step - loss: 1.6711 - sparse_categorical_accuracy: 0.5924 - val_loss: 1.8399 - val_sparse_categorical_accuracy: 0.5298
# Epoch 23/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6666 - sparse_categorical_accuracy: 0.5929
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.55476
# 65/65 [==============================] - 14s 214ms/step - loss: 1.6666 - sparse_categorical_accuracy: 0.5929 - val_loss: 1.8247 - val_sparse_categorical_accuracy: 0.5238
# Epoch 24/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5729 - sparse_categorical_accuracy: 0.6117
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.55476
# 65/65 [==============================] - 13s 195ms/step - loss: 1.5729 - sparse_categorical_accuracy: 0.6117 - val_loss: 2.1289 - val_sparse_categorical_accuracy: 0.4810
# Epoch 25/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6761 - sparse_categorical_accuracy: 0.5847
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.55476
# 65/65 [==============================] - 13s 197ms/step - loss: 1.6761 - sparse_categorical_accuracy: 0.5847 - val_loss: 1.8808 - val_sparse_categorical_accuracy: 0.5536
# Epoch 26/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7339 - sparse_categorical_accuracy: 0.5769
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.55476
# 65/65 [==============================] - 13s 196ms/step - loss: 1.7339 - sparse_categorical_accuracy: 0.5769 - val_loss: 1.8170 - val_sparse_categorical_accuracy: 0.5286
# Epoch 27/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5195 - sparse_categorical_accuracy: 0.6175
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.55476
# 65/65 [==============================] - 13s 200ms/step - loss: 1.5195 - sparse_categorical_accuracy: 0.6175 - val_loss: 1.7394 - val_sparse_categorical_accuracy: 0.5524
# Epoch 28/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4802 - sparse_categorical_accuracy: 0.6179
# Epoch 00028: val_sparse_categorical_accuracy improved from 0.55476 to 0.55595, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 31s 471ms/step - loss: 1.4802 - sparse_categorical_accuracy: 0.6179 - val_loss: 1.7871 - val_sparse_categorical_accuracy: 0.5560
# Epoch 29/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4722 - sparse_categorical_accuracy: 0.6435
# Epoch 00029: val_sparse_categorical_accuracy improved from 0.55595 to 0.56310, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 31s 481ms/step - loss: 1.4722 - sparse_categorical_accuracy: 0.6435 - val_loss: 1.8022 - val_sparse_categorical_accuracy: 0.5631
# Epoch 30/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6033 - sparse_categorical_accuracy: 0.6078
# Epoch 00030: val_sparse_categorical_accuracy improved from 0.56310 to 0.57738, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 31s 481ms/step - loss: 1.6033 - sparse_categorical_accuracy: 0.6078 - val_loss: 1.7227 - val_sparse_categorical_accuracy: 0.5774
# Epoch 31/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4287 - sparse_categorical_accuracy: 0.6512
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.57738
# 65/65 [==============================] - 13s 197ms/step - loss: 1.4287 - sparse_categorical_accuracy: 0.6512 - val_loss: 1.7168 - val_sparse_categorical_accuracy: 0.5500
# Epoch 32/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4206 - sparse_categorical_accuracy: 0.6527
# Epoch 00032: val_sparse_categorical_accuracy did not improve from 0.57738
# 65/65 [==============================] - 16s 250ms/step - loss: 1.4206 - sparse_categorical_accuracy: 0.6527 - val_loss: 1.8544 - val_sparse_categorical_accuracy: 0.5655
# Epoch 33/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5727 - sparse_categorical_accuracy: 0.6324
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.57738
# 65/65 [==============================] - 15s 238ms/step - loss: 1.5727 - sparse_categorical_accuracy: 0.6324 - val_loss: 1.9251 - val_sparse_categorical_accuracy: 0.5476
# Epoch 34/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5067 - sparse_categorical_accuracy: 0.6397
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.57738
# 65/65 [==============================] - 15s 232ms/step - loss: 1.5067 - sparse_categorical_accuracy: 0.6397 - val_loss: 1.7520 - val_sparse_categorical_accuracy: 0.5452
# Epoch 35/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4168 - sparse_categorical_accuracy: 0.6536
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.57738
# 65/65 [==============================] - 16s 240ms/step - loss: 1.4168 - sparse_categorical_accuracy: 0.6536 - val_loss: 1.7730 - val_sparse_categorical_accuracy: 0.5774
# Epoch 36/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3821 - sparse_categorical_accuracy: 0.6700
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.57738
# 65/65 [==============================] - 16s 254ms/step - loss: 1.3821 - sparse_categorical_accuracy: 0.6700 - val_loss: 1.8734 - val_sparse_categorical_accuracy: 0.5690
# Epoch 37/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5024 - sparse_categorical_accuracy: 0.6512
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.57738
# 65/65 [==============================] - 16s 247ms/step - loss: 1.5024 - sparse_categorical_accuracy: 0.6512 - val_loss: 1.8130 - val_sparse_categorical_accuracy: 0.5619
# Epoch 38/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3864 - sparse_categorical_accuracy: 0.6850
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.57738
# 65/65 [==============================] - 14s 220ms/step - loss: 1.3864 - sparse_categorical_accuracy: 0.6850 - val_loss: 1.8601 - val_sparse_categorical_accuracy: 0.5512
# Epoch 39/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3305 - sparse_categorical_accuracy: 0.6879
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.57738
# 65/65 [==============================] - 15s 224ms/step - loss: 1.3305 - sparse_categorical_accuracy: 0.6879 - val_loss: 1.9359 - val_sparse_categorical_accuracy: 0.5524
# Epoch 40/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6237 - sparse_categorical_accuracy: 0.6348
# Epoch 00040: val_sparse_categorical_accuracy improved from 0.57738 to 0.58929, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 33s 514ms/step - loss: 1.6237 - sparse_categorical_accuracy: 0.6348 - val_loss: 1.8238 - val_sparse_categorical_accuracy: 0.5893
# Epoch 41/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4204 - sparse_categorical_accuracy: 0.6840
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.58929
# 65/65 [==============================] - 14s 219ms/step - loss: 1.4204 - sparse_categorical_accuracy: 0.6840 - val_loss: 1.8219 - val_sparse_categorical_accuracy: 0.5655
# Epoch 42/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3897 - sparse_categorical_accuracy: 0.6927
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.58929
# 65/65 [==============================] - 14s 212ms/step - loss: 1.3897 - sparse_categorical_accuracy: 0.6927 - val_loss: 2.0851 - val_sparse_categorical_accuracy: 0.5310
# Epoch 43/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5092 - sparse_categorical_accuracy: 0.6725
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.58929
# 65/65 [==============================] - 17s 260ms/step - loss: 1.5092 - sparse_categorical_accuracy: 0.6725 - val_loss: 1.8711 - val_sparse_categorical_accuracy: 0.5524
# Epoch 44/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4264 - sparse_categorical_accuracy: 0.6860
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.58929
# 65/65 [==============================] - 16s 245ms/step - loss: 1.4264 - sparse_categorical_accuracy: 0.6860 - val_loss: 1.8925 - val_sparse_categorical_accuracy: 0.5750
# Epoch 45/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3690 - sparse_categorical_accuracy: 0.7110
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.58929
# 65/65 [==============================] - 16s 249ms/step - loss: 1.3690 - sparse_categorical_accuracy: 0.7110 - val_loss: 1.8194 - val_sparse_categorical_accuracy: 0.5679
# Epoch 46/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3510 - sparse_categorical_accuracy: 0.7062
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.58929
# 65/65 [==============================] - 15s 232ms/step - loss: 1.3510 - sparse_categorical_accuracy: 0.7062 - val_loss: 1.8177 - val_sparse_categorical_accuracy: 0.5881
# Epoch 47/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3776 - sparse_categorical_accuracy: 0.7028
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.58929
# 65/65 [==============================] - 16s 239ms/step - loss: 1.3776 - sparse_categorical_accuracy: 0.7028 - val_loss: 1.9212 - val_sparse_categorical_accuracy: 0.5774
# Epoch 48/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4299 - sparse_categorical_accuracy: 0.6874
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.58929
# 65/65 [==============================] - 16s 241ms/step - loss: 1.4299 - sparse_categorical_accuracy: 0.6874 - val_loss: 1.8554 - val_sparse_categorical_accuracy: 0.5690
# Epoch 49/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3384 - sparse_categorical_accuracy: 0.7135
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.58929
# 65/65 [==============================] - 16s 242ms/step - loss: 1.3384 - sparse_categorical_accuracy: 0.7135 - val_loss: 1.9060 - val_sparse_categorical_accuracy: 0.5774
# Epoch 50/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5780 - sparse_categorical_accuracy: 0.6811
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.58929
# 65/65 [==============================] - 15s 238ms/step - loss: 1.5780 - sparse_categorical_accuracy: 0.6811 - val_loss: 2.1425 - val_sparse_categorical_accuracy: 0.5774
# Epoch 51/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5164 - sparse_categorical_accuracy: 0.7000
# Epoch 00051: val_sparse_categorical_accuracy improved from 0.58929 to 0.59048, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 36s 551ms/step - loss: 1.5164 - sparse_categorical_accuracy: 0.7000 - val_loss: 1.8838 - val_sparse_categorical_accuracy: 0.5905
# Epoch 52/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3526 - sparse_categorical_accuracy: 0.7279
# Epoch 00052: val_sparse_categorical_accuracy did not improve from 0.59048
# 65/65 [==============================] - 14s 216ms/step - loss: 1.3526 - sparse_categorical_accuracy: 0.7279 - val_loss: 1.9367 - val_sparse_categorical_accuracy: 0.5786
# Epoch 53/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4303 - sparse_categorical_accuracy: 0.7125
# Epoch 00053: val_sparse_categorical_accuracy did not improve from 0.59048
# 65/65 [==============================] - 15s 235ms/step - loss: 1.4303 - sparse_categorical_accuracy: 0.7125 - val_loss: 1.9532 - val_sparse_categorical_accuracy: 0.5643
# Epoch 54/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3737 - sparse_categorical_accuracy: 0.7294
# Epoch 00054: val_sparse_categorical_accuracy improved from 0.59048 to 0.59167, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 33s 510ms/step - loss: 1.3737 - sparse_categorical_accuracy: 0.7294 - val_loss: 1.9717 - val_sparse_categorical_accuracy: 0.5917
# Epoch 55/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3729 - sparse_categorical_accuracy: 0.7366
# Epoch 00055: val_sparse_categorical_accuracy did not improve from 0.59167
# 65/65 [==============================] - 13s 199ms/step - loss: 1.3729 - sparse_categorical_accuracy: 0.7366 - val_loss: 2.0224 - val_sparse_categorical_accuracy: 0.5476
# Epoch 56/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4244 - sparse_categorical_accuracy: 0.7274
# Epoch 00056: val_sparse_categorical_accuracy did not improve from 0.59167
# 65/65 [==============================] - 14s 213ms/step - loss: 1.4244 - sparse_categorical_accuracy: 0.7274 - val_loss: 1.9880 - val_sparse_categorical_accuracy: 0.5821
# Epoch 57/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3554 - sparse_categorical_accuracy: 0.7390
# Epoch 00057: val_sparse_categorical_accuracy did not improve from 0.59167
# 65/65 [==============================] - 14s 213ms/step - loss: 1.3554 - sparse_categorical_accuracy: 0.7390 - val_loss: 2.0068 - val_sparse_categorical_accuracy: 0.5512
# Epoch 58/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3418 - sparse_categorical_accuracy: 0.7400
# Epoch 00058: val_sparse_categorical_accuracy did not improve from 0.59167
# 65/65 [==============================] - 14s 213ms/step - loss: 1.3418 - sparse_categorical_accuracy: 0.7400 - val_loss: 1.9656 - val_sparse_categorical_accuracy: 0.5893
# Epoch 59/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3871 - sparse_categorical_accuracy: 0.7347
# Epoch 00059: val_sparse_categorical_accuracy did not improve from 0.59167
# 65/65 [==============================] - 14s 213ms/step - loss: 1.3871 - sparse_categorical_accuracy: 0.7347 - val_loss: 1.9491 - val_sparse_categorical_accuracy: 0.5857
# Epoch 60/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3228 - sparse_categorical_accuracy: 0.7467
# Epoch 00060: val_sparse_categorical_accuracy did not improve from 0.59167
# 65/65 [==============================] - 14s 215ms/step - loss: 1.3228 - sparse_categorical_accuracy: 0.7467 - val_loss: 2.0927 - val_sparse_categorical_accuracy: 0.5786
# Epoch 61/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3148 - sparse_categorical_accuracy: 0.7458
# Epoch 00061: val_sparse_categorical_accuracy did not improve from 0.59167
# 65/65 [==============================] - 14s 215ms/step - loss: 1.3148 - sparse_categorical_accuracy: 0.7458 - val_loss: 1.9688 - val_sparse_categorical_accuracy: 0.5810
# Epoch 62/500
# 65/65 [==============================] - ETA: 0s - loss: 1.2302 - sparse_categorical_accuracy: 0.7694
# Epoch 00062: val_sparse_categorical_accuracy improved from 0.59167 to 0.59405, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 33s 507ms/step - loss: 1.2302 - sparse_categorical_accuracy: 0.7694 - val_loss: 1.9664 - val_sparse_categorical_accuracy: 0.5940
# Epoch 63/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4149 - sparse_categorical_accuracy: 0.7448
# Epoch 00063: val_sparse_categorical_accuracy did not improve from 0.59405
# 65/65 [==============================] - 13s 200ms/step - loss: 1.4149 - sparse_categorical_accuracy: 0.7448 - val_loss: 1.9671 - val_sparse_categorical_accuracy: 0.5750
# Epoch 64/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4177 - sparse_categorical_accuracy: 0.7448
# Epoch 00064: val_sparse_categorical_accuracy did not improve from 0.59405
# 65/65 [==============================] - 14s 214ms/step - loss: 1.4177 - sparse_categorical_accuracy: 0.7448 - val_loss: 2.1119 - val_sparse_categorical_accuracy: 0.5810
# Epoch 65/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3118 - sparse_categorical_accuracy: 0.7622
# Epoch 00065: val_sparse_categorical_accuracy did not improve from 0.59405
# 65/65 [==============================] - 14s 213ms/step - loss: 1.3118 - sparse_categorical_accuracy: 0.7622 - val_loss: 2.1597 - val_sparse_categorical_accuracy: 0.5786
# Epoch 66/500
# 65/65 [==============================] - ETA: 0s - loss: 1.7472 - sparse_categorical_accuracy: 0.7139
# Epoch 00066: val_sparse_categorical_accuracy did not improve from 0.59405
# 65/65 [==============================] - 14s 214ms/step - loss: 1.7472 - sparse_categorical_accuracy: 0.7139 - val_loss: 2.1917 - val_sparse_categorical_accuracy: 0.5810
# Epoch 67/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4395 - sparse_categorical_accuracy: 0.7646
# Epoch 00067: val_sparse_categorical_accuracy did not improve from 0.59405
# 65/65 [==============================] - 14s 217ms/step - loss: 1.4395 - sparse_categorical_accuracy: 0.7646 - val_loss: 1.9615 - val_sparse_categorical_accuracy: 0.5940
# Epoch 68/500
# 65/65 [==============================] - ETA: 0s - loss: 1.2209 - sparse_categorical_accuracy: 0.7897
# Epoch 00068: val_sparse_categorical_accuracy did not improve from 0.59405
# 65/65 [==============================] - 14s 218ms/step - loss: 1.2209 - sparse_categorical_accuracy: 0.7897 - val_loss: 2.1634 - val_sparse_categorical_accuracy: 0.5619
# Epoch 69/500
# 65/65 [==============================] - ETA: 0s - loss: 1.2866 - sparse_categorical_accuracy: 0.7709
# Epoch 00069: val_sparse_categorical_accuracy did not improve from 0.59405
# 65/65 [==============================] - 14s 219ms/step - loss: 1.2866 - sparse_categorical_accuracy: 0.7709 - val_loss: 2.0976 - val_sparse_categorical_accuracy: 0.5917
# Epoch 70/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3026 - sparse_categorical_accuracy: 0.7631
# Epoch 00070: val_sparse_categorical_accuracy did not improve from 0.59405
# 65/65 [==============================] - 14s 217ms/step - loss: 1.3026 - sparse_categorical_accuracy: 0.7631 - val_loss: 2.3735 - val_sparse_categorical_accuracy: 0.5631
# Epoch 71/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4147 - sparse_categorical_accuracy: 0.7569
# Epoch 00071: val_sparse_categorical_accuracy improved from 0.59405 to 0.62143, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 33s 505ms/step - loss: 1.4147 - sparse_categorical_accuracy: 0.7569 - val_loss: 1.9896 - val_sparse_categorical_accuracy: 0.6214
# Epoch 72/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3083 - sparse_categorical_accuracy: 0.7791
# Epoch 00072: val_sparse_categorical_accuracy improved from 0.62143 to 0.62976, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets
# 65/65 [==============================] - 32s 496ms/step - loss: 1.3083 - sparse_categorical_accuracy: 0.7791 - val_loss: 2.1203 - val_sparse_categorical_accuracy: 0.6298
# Epoch 73/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3520 - sparse_categorical_accuracy: 0.7728
# Epoch 00073: val_sparse_categorical_accuracy did not improve from 0.62976
# 65/65 [==============================] - 13s 202ms/step - loss: 1.3520 - sparse_categorical_accuracy: 0.7728 - val_loss: 2.1585 - val_sparse_categorical_accuracy: 0.5929
# Epoch 74/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4116 - sparse_categorical_accuracy: 0.7583
# Epoch 00074: val_sparse_categorical_accuracy did not improve from 0.62976
# 65/65 [==============================] - 14s
val_sparse_categorical_accuracy did not improve from 0.62976
# 65/65 [==============================] - 16s 240ms/step - loss: 0.7931 - sparse_categorical_accuracy: 0.9354 - val_loss: 2.4786 - val_sparse_categorical_accuracy: 0.6155
# Epoch 167/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3128 - sparse_categorical_accuracy: 0.8669
# Epoch 00167: val_sparse_categorical_accuracy did not improve from 0.62976
# 65/65 [==============================] - 16s 248ms/step - loss: 1.3128 - sparse_categorical_accuracy: 0.8669 - val_loss: 2.7161 - val_sparse_categorical_accuracy: 0.6012
# Epoch 168/500
# 65/65 [==============================] - ETA: 0s - loss: 1.2242 - sparse_categorical_accuracy: 0.8837
# Epoch 00168: val_sparse_categorical_accuracy did not improve from 0.62976
# 65/65 [==============================] - 16s 250ms/step - loss: 1.2242 - sparse_categorical_accuracy: 0.8837 - val_loss: 2.6035 - val_sparse_categorical_accuracy: 0.5893
# Epoch 169/500
# 65/65 [==============================] - ETA: 0s - loss: 0.9562 - sparse_categorical_accuracy: 0.9247
# Epoch 00169: val_sparse_categorical_accuracy did not improve from 0.62976
# 65/65 [==============================] - 16s 252ms/step - loss: 0.9562 - sparse_categorical_accuracy: 0.9247 - val_loss: 2.5764 - val_sparse_categorical_accuracy: 0.6048
# Epoch 170/500
# 65/65 [==============================] - ETA: 0s - loss: 0.8348 - sparse_categorical_accuracy: 0.9329
# Epoch 00170: val_sparse_categorical_accuracy did not improve from 0.62976
# 65/65 [==============================] - 16s 246ms/step - loss: 0.8348 - sparse_categorical_accuracy: 0.9329 - val_loss: 2.5730 - val_sparse_categorical_accuracy: 0.6071
# Epoch 171/500
# 65/65 [==============================] - ETA: 0s - loss: 0.8254 - sparse_categorical_accuracy: 0.9358
# Epoch 00171: val_sparse_categorical_accuracy did not improve from 0.62976
# 65/65 [==============================] - 16s 247ms/step - loss: 0.8254 - sparse_categorical_accuracy: 0.9358 - val_loss: 2.5912 - val_sparse_categorical_accuracy: 0.6190
# Epoch 172/500
# 65/65 [==============================] - ETA: 0s - loss: 0.9759 - sparse_categorical_accuracy: 0.9151Restoring model weights from the end of the best epoch.
#
# Epoch 00172: val_sparse_categorical_accuracy did not improve from 0.62976
# 65/65 [==============================] - 17s 254ms/step - loss: 0.9759 - sparse_categorical_accuracy: 0.9151 - val_loss: 3.4775 - val_sparse_categorical_accuracy: 0.5476
# Epoch 00172: early stopping
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_GFCC_chunks/assets

# %%
# This will combine the predictions of every 1 second chunk of audio from each audiofile. This is done through multiplicative probabilistic voting.
# This functions in the same way as the code used to combine prediction probabilities for the SVM.

X_test_proba = model.predict(GFCC_X_test)

combined_preds = []
y_test_true=[]
for i in Test_index.ID.unique():
    probs = X_test_proba[Test_index[Test_index['ID']==i].index]
    test = y_test[Test_index[Test_index['ID']==i].index][0]
    total_probs=1
    for i in range(probs.shape[0]):
        total_probs = probs[i]*total_probs

    total_probs = total_probs.argmax()
    combined_preds.append(total_probs)
    y_test_true.append(test)

count = 0
for i in range(len(y_test_true)):
    if combined_preds[i]==y_test_true[i]:
        count +=1
GFCC_RNN_score = count/len(y_test_true)
print(f'Final Accuracy Score: {GFCC_RNN_score}')
# Out:
# Final Accuracy Score: 0.8134920634920635

# %% [markdown]
# ### LFCC RNN

# %%
# If a pretrained model exists, we'll load and compile that model. If not, we'll instantiate and compile a new model.
if os.path.exists(os.path.join(PATH,'Models/RNN_model_with_Attention_LFCC_chunks')):
    print('Pretrained model found')
    model=load_model(os.path.join(PATH,'Models/RNN_model_with_Attention_LFCC_chunks'))
    model.summary()
    train = 'no'
else:
    print('No model found, compiling new model')
    model = AttRNNSpeechModel(nCategories=7, inputLength = (LFCC_X_train.shape[1:4]))
    model.compile(optimizer='adam', loss=['sparse_categorical_crossentropy'], metrics=['sparse_categorical_accuracy'])
    model.summary()
    train = 'yes'
# Out:
# Pretrained model found
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 87, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 87, 64, 10)   60          input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 87, 64, 10)   40          conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 87, 64, 1)    51          batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 87, 64, 1)    4           conv2d_5[0][0]
# __________________________________________________________________________________________________
# squeeze_last_dim (Lambda)       (None, 87, 64)       0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 87, 128)      66048       squeeze_last_dim[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 87, 128)      98816       bidirectional_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 128)          0           bidirectional_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          16512       lambda_2[0][0]
# __________________________________________________________________________________________________
# dot_4 (Dot)                     (None, 87)           0           dense_6[0][0]
#                                                                  bidirectional_5[0][0]
# __________________________________________________________________________________________________
# attSoftmax (Softmax)            (None, 87)           0           dot_4[0][0]
# __________________________________________________________________________________________________
# dot_5 (Dot)                     (None, 128)          0           attSoftmax[0][0]
#                                                                  bidirectional_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           8256        dot_5[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 32)           2080        dense_7[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 7)            231         dense_8[0][0]
# ==================================================================================================
# Total params: 192,098
# Trainable params: 192,076
# Non-trainable params: 22
# __________________________________________________________________________________________________

# %%
# # Uncomment this to continue training the loaded model
# train = 'yes'

# %%
if train =='yes':
    earlystopper = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=100,
                                 verbose=1, restore_best_weights=True)
    checkpointer = ModelCheckpoint('/Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_LFCC_chunks', 
                                   monitor='val_sparse_categorical_accuracy', 
                                   verbose=1, 
                                   save_best_only=True)


    model.fit(LFCC_X_train, y_train,
              epochs = 500,
              verbose = 1,
              validation_data=(LFCC_X_test, y_test),
              shuffle=True,
              callbacks=[earlystopper, checkpointer])
    model.save('/Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_LFCC_chunks')

# %%
# This will combine the predictions of every 1 second chunk of audio from each audiofile. This is done through multiplicative probabilistic voting.
# This functions in the same way as the code used to combine prediction probabilities for the SVM.
X_test_proba = model.predict(LFCC_X_test)

combined_preds = []
y_test_true=[]
for i in Test_index.ID.unique():
    probs = X_test_proba[Test_index[Test_index['ID']==i].index]
    test = y_test[Test_index[Test_index['ID']==i].index][0]
    total_probs=1
    for i in range(probs.shape[0]):
        total_probs = probs[i]*total_probs

    total_probs = total_probs.argmax()
    combined_preds.append(total_probs)
    y_test_true.append(test)

count = 0
for i in range(len(y_test_true)):
    if combined_preds[i]==y_test_true[i]:
        count +=1
LFCC_RNN_score = count/len(y_test_true)
print(f'Final Accuracy Score: {LFCC_RNN_score}')
# Out:
# Final Accuracy Score: 0.7182539682539683

# %% [markdown]
# ### Fusion RNN

# %%
# If a pretrained model exists, we'll load and compile that model. If not, we'll instantiate and compile a new model.
if os.path.exists(os.path.join(PATH,'Models/RNN_model_with_Attention_Fusion')):
    print('Pretrained model found')
    model=load_model(os.path.join(PATH,'Models/RNN_model_with_Attention_Fusion'))
    model.summary()
    train = 'no'
else:
    print('No model found, compiling new model')
    model = AttRNNSpeechModel(nCategories=7, inputLength = (Fusion_X_train.shape[1:4]))
    model.compile(optimizer='adam', loss=['sparse_categorical_crossentropy'], metrics=['sparse_categorical_accuracy'])
    model.summary()
    train = 'yes'
# Out:
# Pretrained model found
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 87, 224, 1)] 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 87, 224, 10)  60          input[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 87, 224, 10)  40          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 87, 224, 1)   51          batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 87, 224, 1)   4           conv2d_1[0][0]
# __________________________________________________________________________________________________
# squeeze_last_dim (Lambda)       (None, 87, 224)      0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 87, 128)      147968      squeeze_last_dim[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 87, 128)      98816       bidirectional[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 128)          0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          16512       lambda[0][0]
# __________________________________________________________________________________________________
# dot (Dot)                       (None, 87)           0           dense[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# attSoftmax (Softmax)            (None, 87)           0           dot[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 128)          0           attSoftmax[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dot_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dense_1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 7)            231         dense_2[0][0]
# ==================================================================================================
# Total params: 274,018
# Trainable params: 273,996
# Non-trainable params: 22
# __________________________________________________________________________________________________

# %%
# # Uncomment this to continue training the loaded model
# train = 'yes'

# %%
if train =='yes':
    earlystopper = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=100,
                                 verbose=1, restore_best_weights=True)
    checkpointer = ModelCheckpoint('/Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion', 
                                   monitor='val_sparse_categorical_accuracy', 
                                   verbose=1, 
                                   save_best_only=True)


    model.fit(Fusion_X_train, y_train,
              epochs = 500,
              verbose = 1,
              validation_data=(Fusion_X_test, y_test),
              shuffle=True,
              callbacks=[earlystopper, checkpointer])
    model.save('/Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion')
# Out:
# Epoch 1/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4385 - sparse_categorical_accuracy: 0.7593
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.57262, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion/assets
# 65/65 [==============================] - 43s 669ms/step - loss: 1.4385 - sparse_categorical_accuracy: 0.7593 - val_loss: 2.2048 - val_sparse_categorical_accuracy: 0.5726
# Epoch 2/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5801 - sparse_categorical_accuracy: 0.7530
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.57262 to 0.60476, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion/assets
# 65/65 [==============================] - 45s 687ms/step - loss: 1.5801 - sparse_categorical_accuracy: 0.7530 - val_loss: 2.0335 - val_sparse_categorical_accuracy: 0.6048
# Epoch 3/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3482 - sparse_categorical_accuracy: 0.7800
# Epoch 00003: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 20s 315ms/step - loss: 1.3482 - sparse_categorical_accuracy: 0.7800 - val_loss: 2.0211 - val_sparse_categorical_accuracy: 0.5940
# Epoch 4/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5265 - sparse_categorical_accuracy: 0.7569
# Epoch 00004: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 20s 311ms/step - loss: 1.5265 - sparse_categorical_accuracy: 0.7569 - val_loss: 2.1022 - val_sparse_categorical_accuracy: 0.5976
# Epoch 5/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4229 - sparse_categorical_accuracy: 0.7873
# Epoch 00005: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 20s 315ms/step - loss: 1.4229 - sparse_categorical_accuracy: 0.7873 - val_loss: 2.3926 - val_sparse_categorical_accuracy: 0.5738
# Epoch 6/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6515 - sparse_categorical_accuracy: 0.7559
# Epoch 00006: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 20s 314ms/step - loss: 1.6515 - sparse_categorical_accuracy: 0.7559 - val_loss: 2.2545 - val_sparse_categorical_accuracy: 0.6000
# Epoch 7/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4868 - sparse_categorical_accuracy: 0.7781
# Epoch 00007: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 20s 312ms/step - loss: 1.4868 - sparse_categorical_accuracy: 0.7781 - val_loss: 2.1345 - val_sparse_categorical_accuracy: 0.5952
# Epoch 8/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3727 - sparse_categorical_accuracy: 0.7887
# Epoch 00008: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 20s 313ms/step - loss: 1.3727 - sparse_categorical_accuracy: 0.7887 - val_loss: 2.0437 - val_sparse_categorical_accuracy: 0.5940
# Epoch 9/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4829 - sparse_categorical_accuracy: 0.7665
# Epoch 00009: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 21s 315ms/step - loss: 1.4829 - sparse_categorical_accuracy: 0.7665 - val_loss: 2.2640 - val_sparse_categorical_accuracy: 0.6036
# Epoch 10/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4592 - sparse_categorical_accuracy: 0.7892
# Epoch 00010: val_sparse_categorical_accuracy did not improve from 0.60476
# 65/65 [==============================] - 22s 336ms/step - loss: 1.4592 - sparse_categorical_accuracy: 0.7892 - val_loss: 2.1555 - val_sparse_categorical_accuracy: 0.5976
# Epoch 11/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4946 - sparse_categorical_accuracy: 0.7791
# Epoch 00011: val_sparse_categorical_accuracy improved from 0.60476 to 0.61071, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion/assets
# 65/65 [==============================] - 43s 656ms/step - loss: 1.4946 - sparse_categorical_accuracy: 0.7791 - val_loss: 2.2079 - val_sparse_categorical_accuracy: 0.6107
# Epoch 12/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4069 - sparse_categorical_accuracy: 0.7844
# Epoch 00012: val_sparse_categorical_accuracy did not improve from 0.61071
# 65/65 [==============================] - 22s 344ms/step - loss: 1.4069 - sparse_categorical_accuracy: 0.7844 - val_loss: 2.2165 - val_sparse_categorical_accuracy: 0.5893
# Epoch 13/500
# 65/65 [==============================] - ETA: 0s - loss: 1.9276 - sparse_categorical_accuracy: 0.6980
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.61071
# 65/65 [==============================] - 24s 371ms/step - loss: 1.9276 - sparse_categorical_accuracy: 0.6980 - val_loss: 2.0620 - val_sparse_categorical_accuracy: 0.6071
# Epoch 14/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4113 - sparse_categorical_accuracy: 0.7680
# Epoch 00014: val_sparse_categorical_accuracy improved from 0.61071 to 0.62738, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion/assets
# 65/65 [==============================] - 51s 783ms/step - loss: 1.4113 - sparse_categorical_accuracy: 0.7680 - val_loss: 1.8990 - val_sparse_categorical_accuracy: 0.6274
# Epoch 15/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4050 - sparse_categorical_accuracy: 0.7829
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.62738
# 65/65 [==============================] - 21s 327ms/step - loss: 1.4050 - sparse_categorical_accuracy: 0.7829 - val_loss: 2.1032 - val_sparse_categorical_accuracy: 0.6119
# Epoch 16/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3625 - sparse_categorical_accuracy: 0.7988
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.62738
# 65/65 [==============================] - 23s 349ms/step - loss: 1.3625 - sparse_categorical_accuracy: 0.7988 - val_loss: 2.0290 - val_sparse_categorical_accuracy: 0.6095
# Epoch 17/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3282 - sparse_categorical_accuracy: 0.8167
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.62738
# 65/65 [==============================] - 25s 381ms/step - loss: 1.3282 - sparse_categorical_accuracy: 0.8167 - val_loss: 2.1742 - val_sparse_categorical_accuracy: 0.5929
# Epoch 18/500
# 65/65 [==============================] - ETA: 0s - loss: 1.
500
# 65/65 [==============================] - ETA: 0s - loss: 1.3124 - sparse_categorical_accuracy: 0.8789
# Epoch 00084: val_sparse_categorical_accuracy did not improve from 0.62857
# 65/65 [==============================] - 22s 333ms/step - loss: 1.3124 - sparse_categorical_accuracy: 0.8789 - val_loss: 2.8344 - val_sparse_categorical_accuracy: 0.5988
# Epoch 85/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5877 - sparse_categorical_accuracy: 0.8485
# Epoch 00085: val_sparse_categorical_accuracy did not improve from 0.62857
# 65/65 [==============================] - 22s 335ms/step - loss: 1.5877 - sparse_categorical_accuracy: 0.8485 - val_loss: 2.9575 - val_sparse_categorical_accuracy: 0.6107
# Epoch 86/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6045 - sparse_categorical_accuracy: 0.8437
# Epoch 00086: val_sparse_categorical_accuracy did not improve from 0.62857
# 65/65 [==============================] - 21s 330ms/step - loss: 1.6045 - sparse_categorical_accuracy: 0.8437 - val_loss: 2.6290 - val_sparse_categorical_accuracy: 0.6143
# Epoch 87/500
# 65/65 [==============================] - ETA: 0s - loss: 1.1970 - sparse_categorical_accuracy: 0.8939
# Epoch 00087: val_sparse_categorical_accuracy improved from 0.62857 to 0.63214, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion/assets
# 65/65 [==============================] - 42s 642ms/step - loss: 1.1970 - sparse_categorical_accuracy: 0.8939 - val_loss: 2.4520 - val_sparse_categorical_accuracy: 0.6321
# Epoch 88/500
# 65/65 [==============================] - ETA: 0s - loss: 1.0128 - sparse_categorical_accuracy: 0.9233
# Epoch 00088: val_sparse_categorical_accuracy did not improve from 0.63214
# 65/65 [==============================] - 21s 329ms/step - loss: 1.0128 - sparse_categorical_accuracy: 0.9233 - val_loss: 2.4537 - val_sparse_categorical_accuracy: 0.6214
# Epoch 89/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4066 - sparse_categorical_accuracy: 0.8726
# Epoch 00089: val_sparse_categorical_accuracy did not improve from 0.63214
# 65/65 [==============================] - 21s 325ms/step - loss: 1.4066 - sparse_categorical_accuracy: 0.8726 - val_loss: 2.8689 - val_sparse_categorical_accuracy: 0.6000
# Epoch 90/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3915 - sparse_categorical_accuracy: 0.8717
# Epoch 00090: val_sparse_categorical_accuracy did not improve from 0.63214
# 65/65 [==============================] - 22s 333ms/step - loss: 1.3915 - sparse_categorical_accuracy: 0.8717 - val_loss: 2.7947 - val_sparse_categorical_accuracy: 0.6095
# Epoch 91/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3968 - sparse_categorical_accuracy: 0.8751
# Epoch 00091: val_sparse_categorical_accuracy did not improve from 0.63214
# 65/65 [==============================] - 21s 330ms/step - loss: 1.3968 - sparse_categorical_accuracy: 0.8751 - val_loss: 2.7473 - val_sparse_categorical_accuracy: 0.6107
# Epoch 92/500
# 65/65 [==============================] - ETA: 0s - loss: 1.2647 - sparse_categorical_accuracy: 0.8924
# Epoch 00092: val_sparse_categorical_accuracy did not improve from 0.63214
# 65/65 [==============================] - 21s 330ms/step - loss: 1.2647 - sparse_categorical_accuracy: 0.8924 - val_loss: 2.7650 - val_sparse_categorical_accuracy: 0.6036
# Epoch 93/500
# 65/65 [==============================] - ETA: 0s - loss: 1.2628 - sparse_categorical_accuracy: 0.8997
# Epoch 00093: val_sparse_categorical_accuracy did not improve from 0.63214
# 65/65 [==============================] - 22s 334ms/step - loss: 1.2628 - sparse_categorical_accuracy: 0.8997 - val_loss: 2.9050 - val_sparse_categorical_accuracy: 0.6310
# Epoch 94/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6902 - sparse_categorical_accuracy: 0.8326
# Epoch 00094: val_sparse_categorical_accuracy did not improve from 0.63214
# 65/65 [==============================] - 21s 329ms/step - loss: 1.6902 - sparse_categorical_accuracy: 0.8326 - val_loss: 3.1270 - val_sparse_categorical_accuracy: 0.5738
# Epoch 95/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6234 - sparse_categorical_accuracy: 0.8476
# Epoch 00095: val_sparse_categorical_accuracy did not improve from 0.63214
# 65/65 [==============================] - 21s 330ms/step - loss: 1.6234 - sparse_categorical_accuracy: 0.8476 - val_loss: 2.5883 - val_sparse_categorical_accuracy: 0.6071
# Epoch 96/500
# 65/65 [==============================] - ETA: 0s - loss: 1.1485 - sparse_categorical_accuracy: 0.9108
# Epoch 00096: val_sparse_categorical_accuracy did not improve from 0.63214
# 65/65 [==============================] - 21s 330ms/step - loss: 1.1485 - sparse_categorical_accuracy: 0.9108 - val_loss: 2.4716 - val_sparse_categorical_accuracy: 0.6214
# Epoch 97/500
# 65/65 [==============================] - ETA: 0s - loss: 1.0332 - sparse_categorical_accuracy: 0.9243
# Epoch 00097: val_sparse_categorical_accuracy improved from 0.63214 to 0.64881, saving model to /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion/assets
# 65/65 [==============================] - 41s 625ms/step - loss: 1.0332 - sparse_categorical_accuracy: 0.9243 - val_loss: 2.5629 - val_sparse_categorical_accuracy: 0.6488
# Epoch 98/500
# 65/65 [==============================] - ETA: 0s - loss: 1.1917 - sparse_categorical_accuracy: 0.9050
# Epoch 00098: val_sparse_categorical_accuracy did not improve from 0.64881
# 65/65 [==============================] - 21s 330ms/step - loss: 1.1917 - sparse_categorical_accuracy: 0.9050 - val_loss: 2.6679 - val_sparse_categorical_accuracy: 0.6286
# Epoch 99/500
# 65/65 [==============================] - ETA: 0s - loss: 1.2701 - sparse_categorical_accuracy: 0.8934
# Epoch 00099: val_sparse_categorical_accuracy did not improve from 0.64881
# 65/65 [==============================] - 21s 330ms/step - loss: 1.2701 - sparse_categorical_accuracy: 0.8934 - val_loss: 2.7018 - val_sparse_categorical_accuracy: 0.6345
# Epoch 100/500
# 65/65 [==============================] - ETA: 0s - loss: 1.4411 - sparse_categorical_accuracy: 0.8808
# Epoch 00100: val_sparse_categorical_accuracy did not improve from 0.64881
# 65/65 [==============================] - 21s 327ms/step - loss: 1.4411 - sparse_categorical_accuracy: 0.8808 - val_loss: 2.9508 - val_sparse_categorical_accuracy: 0.6202
# Epoch 101/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5785 - sparse_categorical_accuracy: 0.8582
# Epoch 00101: val_sparse_categorical_accuracy did not improve from 0.64881
# 65/65 [==============================] - 21s 329ms/step - loss: 1.5785 - sparse_categorical_accuracy: 0.8582 - val_loss: 2.6310 - val_sparse_categorical_accuracy: 0.6024
# Epoch 102/500
# 65/65 [==============================] - ETA: 0s - loss: 1.0812 - sparse_categorical_accuracy: 0.9214
# Epoch 00102: val_sparse_categorical_accuracy did not improve from 0.64881
# 65/65 [==============================] - 20s 313ms/step - loss: 1.0812 - sparse_categorical_accuracy: 0.9214 - val_loss: 2.4477 - val_sparse_categorical_accuracy: 0.6369
# Epoch 103/500
# 65/65 [==============================] - ETA: 0s - loss: 1.0417 - sparse_categorical_accuracy: 0.9243
# Epoch 00103: val_sparse_categorical_accuracy did not improve from 0.64881
# 65/65 [==============================] - 20s 303ms/step - loss: 1.0417 - sparse_categorical_accuracy: 0.9243 - val_loss: 2.8053 - val_sparse_categorical_accuracy: 0.6107
# Epoch 104/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3280 - sparse_categorical_accuracy: 0.8847
# Epoch 00104: val_sparse_categorical_accuracy did not improve from 0.64881
# 65/65 [==============================] - 29s 443ms/step - loss: 1.3280 - sparse_categorical_accuracy: 0.8847 - val_loss: 2.7798 - val_sparse_categorical_accuracy: 0.6024
# Epoch 105/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3681 - sparse_categorical_accuracy: 0.8837
# Epoch 00105: val_sparse_categorical_accuracy did not improve from 0.64881
# 65/65 [==============================] - 22s 339ms/step - loss: 1.3681 - sparse_categorical_accuracy: 0.8837 - val_loss: 2.9412 - val_sparse_categorical_accuracy: 0.5881
# Epoch 106/500
# 65/65 [==============================] - ETA: 0s - loss: 1.3482 - sparse_categorical_accuracy: 0.8876
# Epoch 00106: val_sparse_categorical_accuracy did not improve from 0.64881
# 65/65 [==============================] - 21s
val_sparse_categorical_accuracy did not improve from 0.66905
# 65/65 [==============================] - 25s 383ms/step - loss: 0.6257 - sparse_categorical_accuracy: 0.9706 - val_loss: 3.0032 - val_sparse_categorical_accuracy: 0.6143
# Epoch 436/500
# 65/65 [==============================] - ETA: 0s - loss: 1.5382 - sparse_categorical_accuracy: 0.8760
# Epoch 00436: val_sparse_categorical_accuracy did not improve from 0.66905
# 65/65 [==============================] - 27s 418ms/step - loss: 1.5382 - sparse_categorical_accuracy: 0.8760 - val_loss: 3.2629 - val_sparse_categorical_accuracy: 0.6048
# Epoch 437/500
# 65/65 [==============================] - ETA: 0s - loss: 1.6776 - sparse_categorical_accuracy: 0.8635
# Epoch 00437: val_sparse_categorical_accuracy did not improve from 0.66905
# 65/65 [==============================] - 26s 394ms/step - loss: 1.6776 - sparse_categorical_accuracy: 0.8635 - val_loss: 2.6653 - val_sparse_categorical_accuracy: 0.6417
# Epoch 438/500
# 65/65 [==============================] - ETA: 0s - loss: 0.9897 - sparse_categorical_accuracy: 0.9551
# Epoch 00438: val_sparse_categorical_accuracy did not improve from 0.66905
# 65/65 [==============================] - 24s 375ms/step - loss: 0.9897 - sparse_categorical_accuracy: 0.9551 - val_loss: 2.3336 - val_sparse_categorical_accuracy: 0.6524
# Epoch 439/500
# 65/65 [==============================] - ETA: 0s - loss: 0.6558 - sparse_categorical_accuracy: 0.9865Restoring model weights from the end of the best epoch.
#
# Epoch 00439: val_sparse_categorical_accuracy did not improve from 0.66905
# 65/65 [==============================] - 29s 442ms/step - loss: 0.6558 - sparse_categorical_accuracy: 0.9865 - val_loss: 2.2696 - val_sparse_categorical_accuracy: 0.6583
# Epoch 00439: early stopping
# INFO:tensorflow:Assets written to: /Users/coleslatt/Documents/Data Science/Brainstation/Projects/Capstone Project/Models/RNN_model_with_Attention_Fusion/assets

# %%
# This will combine the predictions of every 1 second chunk of audio from each audiofile. This is done through multiplicative probabilistic voting.
# This functions in the same way as the code used to combine prediction probabilities for the SVM.
X_test_proba = model.predict(Fusion_X_test)

combined_preds = []
y_test_true=[]
for i in Test_index.ID.unique():
    probs = X_test_proba[Test_index[Test_index['ID']==i].index]
    test = y_test[Test_index[Test_index['ID']==i].index][0]
    total_probs=1
    for i in range(probs.shape[0]):
        total_probs = probs[i]*total_probs

    total_probs = total_probs.argmax()
    combined_preds.append(total_probs)
    y_test_true.append(test)

count = 0
for i in range(len(y_test_true)):
    if combined_preds[i]==y_test_true[i]:
        count +=1
FUSION_RNN_score = count/len(y_test_true)
print(f'Final Accuracy Score: {FUSION_RNN_score}')
# Out:
# Final Accuracy Score: 0.8452380952380952

# %% [markdown]
# ## Final Results

# %%
print(f'Kernel SVM with LFCC score: {round(LFCC_SVM_Score*100,2)}%')
print(f'RNN with MFCC score: {round(MFCC_RNN_score*100,2)}%')
print(f'RNN with GFCC score: {round(GFCC_RNN_score*100,2)}%')
print(f'RNN with LFCC score: {round(LFCC_RNN_score*100,2)}%')
print(f'RNN with Feature Fusion score: {round(FUSION_RNN_score*100,2)}%')
# Out:
# Kernel SVM with LFCC score: 81.75%
# RNN with MFCC score: 79.76%
# RNN with GFCC score: 81.35%
# RNN with LFCC score: 71.83%
# RNN with Feature Fusion score: 84.52%
